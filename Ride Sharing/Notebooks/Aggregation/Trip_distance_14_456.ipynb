# %%
import pandas as pd
import geopandas as gp
from fiona.crs import from_epsg
import shapely
import matplotlib.pylab as plt
import csv
import dateutil
import os
from shapely.geometry import Point
# %matplotlib inline

# %%
# files for each year like:
## <neighborhood/borough of pick up>,<distance>,<ended on Manhattan (0/1)>,<number of trips>.

# %%
def clean_columns(data,year):
    
    data.columns = map(lambda x: x.strip(), list(data.columns))
    data.columns = map(lambda x: x.lower(), list(data.columns))
        
    if (year == '2014') | (year == '2013'):
        data.drop([u'vendor_id', u'passenger_count', u'rate_code', u'store_and_fwd_flag',
                   'dropoff_longitude','dropoff_latitude', u'payment_type',u'fare_amount', 
                   u'surcharge', u'mta_tax', u'tip_amount',
                   u'tolls_amount', u'total_amount'], axis = 1, inplace = True)
        
    elif year == '2015':
        data.drop([u'vendorid', u'passenger_count', u'ratecodeid', u'store_and_fwd_flag',
                   u'dropoff_longitude', u'dropoff_latitude', u'payment_type',
                   u'fare_amount', u'extra', u'mta_tax', u'tip_amount', u'tolls_amount',
                   u'improvement_surcharge', u'total_amount'], axis = 1, inplace = True)
    
    elif year == '2016':    
        data.drop([u'vendorid', u'passenger_count', u'ratecodeid', u'store_and_fwd_flag',
                   u'dropoff_longitude', u'dropoff_latitude', u'payment_type',
                   u'fare_amount', u'extra', u'mta_tax', u'tip_amount', u'tolls_amount',
                   u'improvement_surcharge', u'total_amount'], axis = 1, inplace = True)
    
    data.columns = ['date', 'dropoff_datetime', 'trip_distance', 
                    'pickup_longitude', 'pickup_latitude']
    
    return data

# %%
def segregate(data):
    
    man_upper = [24,151,238,75, 236, 263, 262, 239, 143, 142, 237, 141, 140]
    man_lower = [4, 79,113, 114, 249, 158, 125, 211, 144, 148, 232, 13, 231, 45,209,87,88,12,261]
    bk_dwn = [17,  25,  33, 49,  40,  34, 52, 54, 65, 106, 97, 66, 181, 189, 190, 195]
    bk_br = [11, 14, 22, 26, 67, 111, 227, 228]
    
    groups = range(0,25)
    groups.extend([25,data.trip_distance.max()])
    data['trip_cat'] = pd.cut(data.trip_distance, groups, labels=groups[:-1])
    data_man_upper = data[data.LocationID.isin(man_upper)]
    data_man_lower = data[data.LocationID.isin(man_lower)]
    data_bk_dwn = data[data.LocationID.isin(bk_dwn)]
    data_bk_br = data[data.LocationID.isin(bk_br)]
    
    data_man_upper = data_man_upper.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_man_lower = data_man_lower.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_bk_dwn = data_bk_dwn.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_bk_br = data_bk_br.groupby(['trip_cat']).agg({'LocationID':'count'})
        
    data_man_upper.reset_index(inplace=True)
    data_man_lower.reset_index(inplace=True)
    data_bk_dwn.reset_index(inplace=True)
    data_bk_br.reset_index(inplace=True)
    

    data_man_upper.loc[:, 'neighbourhood'] =  'upper_manhattan'
    data_man_lower.loc[:, 'neighbourhood'] =  'lower_manhattan'
    data_bk_dwn.loc[:, 'neighbourhood'] =  'Downtown_Bk'
    data_bk_br.loc[:, 'neighbourhood'] =  'Bayridge_bk'
    
    data = pd.concat([data_man_upper, data_man_lower, data_bk_dwn, data_bk_br], axis=0, ignore_index=True)
    data.columns = ['trip_cat', 'num_rides', 'neighbourhood']
    
    return data

# %%
def data_aggregator(data, tzone):
    
#     data["date"] = pd.to_datetime(data["date"])

    crs = {'init': 'epsg:4326', 'no_defs': True}
    geometry = [Point(xy) for xy in zip(data["pickup_longitude"], data["pickup_latitude"])]
    data = data.drop(["pickup_longitude", "pickup_latitude"], axis=1)
    data = gp.GeoDataFrame(data, crs=crs, geometry=geometry)

    print "Spatially joining data and taxi zones"
    data_geo = gp.sjoin(tzones, data) 
    data_geo = data_geo[['LocationID','trip_distance']]   
    
    print "Segregating"
    data_agg = segregate(data_geo)
    
    return data_agg

# %%
# Read data by month
def yellow_taxi(tzones): 
    
    
    if not (os.path.isdir("../../Data/Dist_agg")):
        print "Creating Folder Data/Dist_agg"
        os.system("mkdir ../../Data/Dist_agg")
        
#     year = ['2014', '2015']
#     months = ['01','02','03','04','05','06','07','08','09','10','11','12']
    year = ['2015']
#     months = ['04','05','06']
    months = ['06']

    yellow = []
    for y in year:
        for m in months:
            
            print "Reading Data/Yellow/yellow_tripdata_" + y + "-" + m + ".csv"
            data = pd.read_csv("../../Data/Yellow/yellow_tripdata_" + y + "-" + m + ".csv")
            print "Cleaning columns"
            data = clean_columns(data, y)
            print "Aggregating data"
            data_agg = data_aggregator(data, tzones)
            data_agg.to_csv("../../Data/Dist_agg/yellow_"+ y + "-" + m + ".csv")
            print 'Done'
            yellow.append(data_agg)
    
    return yellow

# %%
tzones = gp.read_file("../../Data/taxi_zones/taxi_zones_updated.shp")
tzones.to_crs(epsg=4326, inplace=True)

# %%
data = yellow_taxi(tzones)
# Out:
# Reading Data/Yellow/yellow_tripdata_2015-06.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done

# %%
def clean_columns_green(data,year, month):
    
    data.columns = map(lambda x: x.strip(), list(data.columns))
    data.columns = map(lambda x: x.lower(), list(data.columns))
    
    if (((year == '2015') & (month in ['07', '08', '09', '10', '11', '12'])) | (year == '2016')):
        data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                   u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                   u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                   u'improvement_surcharge', u'total_amount', u'payment_type',
                   u'trip_type'], axis = 1, inplace = True)
    
    else: 
    
        cols = data.columns
        data.reset_index(inplace=True)
        data = data.iloc[:,:len(cols)]
        data.columns = cols
        
        if year == '2015':
            data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                       u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                       u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                       u'improvement_surcharge', u'total_amount', u'payment_type',
                       u'trip_type'], axis = 1, inplace = True)
        
        elif (year == '2014') | (year == '2013'):
            data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                       u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                       u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                       u'total_amount', u'payment_type', u'trip_type'], axis = 1, inplace = True)
               
    data.columns = ['date', 'dropoff_datetime','pickup_longitude', 'pickup_latitude', 
                    'trip_distance']
    
    return data

# Read data by month
def green_taxi(tzones): 
    
    
    if not (os.path.isdir("../../Data/Dist_agg")):
        print "Creating Folder Data/Dist_agg"
        os.system("mkdir ../../Data/Dist_agg")
        
#     year = ['2014', '2015']
#     months = ['01','02','03','04','05','06','07','08','09','10','11','12']
    year = ['2014', '2015']
    months = ['04','05','06']

    green = []
    for y in year:
        for m in months:
            
            print "Reading Data/Green/green_tripdata_" + y + "-" + m + ".csv"
            data = pd.read_csv("../../Data/Green/green_tripdata_" + y + "-" + m + ".csv")
            print "Cleaning columns"
            data = clean_columns_green(data, y, m)
            print "Aggregating data"
            data_agg = data_aggregator(data, tzones)
            data_agg.to_csv("../../Data/Dist_agg/green_"+ y + "-" + m + ".csv")
            print 'Done'
            green.append(data_agg)
    
    return green

# %%
green_taxi(tzones)
# Out:
# Reading Data/Green/green_tripdata_2014-04.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2014-05.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2014-06.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-04.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-05.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-06.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# [    trip_cat  num_rides    neighbourhood
#  0          0      15280  upper_manhattan
#  1          1      23337  upper_manhattan
#  2          2      11109  upper_manhattan
#  3          3       5729  upper_manhattan
#  4          4       3378  upper_manhattan
#  5          5       2453  upper_manhattan
#  6          6       1778  upper_manhattan
#  7          7       1463  upper_manhattan
#  8          8        952  upper_manhattan
#  9          9        525  upper_manhattan
#  10        10        337  upper_manhattan
#  11        11        201  upper_manhattan
#  12        12        126  upper_manhattan
#  13        13         96  upper_manhattan
#  14        14         68  upper_manhattan
#  15        15         76  upper_manhattan
#  16        16         58  upper_manhattan
#  17        17        137  upper_manhattan
#  18        18        207  upper_manhattan
#  19        19         41  upper_manhattan
#  20        20         22  upper_manhattan
#  21        21         11  upper_manhattan
#  22        22         17  upper_manhattan
#  23        23          5  upper_manhattan
#  24        24          4  upper_manhattan
#  25        25         20  upper_manhattan
#  26         0          9  lower_manhattan
#  27         1         13  lower_manhattan
#  28         2         17  lower_manhattan
#  29         3         22  lower_manhattan
#  ..       ...        ...              ...
#  74        22         31      Downtown_Bk
#  75        23         24      Downtown_Bk
#  76        24         29      Downtown_Bk
#  77        25        146      Downtown_Bk
#  78         0        523      Bayridge_bk
#  79         1        835      Bayridge_bk
#  80         2        588      Bayridge_bk
#  81         3        372      Bayridge_bk
#  82         4        258      Bayridge_bk
#  83         5        202      Bayridge_bk
#  84         6        156      Bayridge_bk
#  85         7        155      Bayridge_bk
#  86         8        114      Bayridge_bk
#  87         9         96      Bayridge_bk
#  88        10         69      Bayridge_bk
#  89        11         53      Bayridge_bk
#  90        12         37      Bayridge_bk
#  91        13         36      Bayridge_bk
#  92        14         42      Bayridge_bk
#  93        15         20      Bayridge_bk
#  94        16         19      Bayridge_bk
#  95        17          7      Bayridge_bk
#  96        18         10      Bayridge_bk
#  97        19          5      Bayridge_bk
#  98        20          0      Bayridge_bk
#  99        21          4      Bayridge_bk
#  100       22          6      Bayridge_bk
#  101       23          1      Bayridge_bk
#  102       24          3      Bayridge_bk
#  103       25          5      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      14860  upper_manhattan
#  1          1      24047  upper_manhattan
#  2          2      11304  upper_manhattan
#  3          3       5583  upper_manhattan
#  4          4       3322  upper_manhattan
#  5          5       2625  upper_manhattan
#  6          6       1805  upper_manhattan
#  7          7       1516  upper_manhattan
#  8          8        932  upper_manhattan
#  9          9        475  upper_manhattan
#  10        10        289  upper_manhattan
#  11        11        221  upper_manhattan
#  12        12        140  upper_manhattan
#  13        13         90  upper_manhattan
#  14        14         93  upper_manhattan
#  15        15         67  upper_manhattan
#  16        16         66  upper_manhattan
#  17        17        182  upper_manhattan
#  18        18        268  upper_manhattan
#  19        19         69  upper_manhattan
#  20        20         25  upper_manhattan
#  21        21         17  upper_manhattan
#  22        22         16  upper_manhattan
#  23        23         10  upper_manhattan
#  24        24          5  upper_manhattan
#  25        25         32  upper_manhattan
#  26         0          3  lower_manhattan
#  27         1          9  lower_manhattan
#  28         2         32  lower_manhattan
#  29         3         31  lower_manhattan
#  ..       ...        ...              ...
#  74        22         31      Downtown_Bk
#  75        23         24      Downtown_Bk
#  76        24         31      Downtown_Bk
#  77        25        167      Downtown_Bk
#  78         0        656      Bayridge_bk
#  79         1       1149      Bayridge_bk
#  80         2        896      Bayridge_bk
#  81         3        599      Bayridge_bk
#  82         4        341      Bayridge_bk
#  83         5        283      Bayridge_bk
#  84         6        307      Bayridge_bk
#  85         7        288      Bayridge_bk
#  86         8        185      Bayridge_bk
#  87         9        154      Bayridge_bk
#  88        10        110      Bayridge_bk
#  89        11         71      Bayridge_bk
#  90        12         76      Bayridge_bk
#  91        13         57      Bayridge_bk
#  92        14         46      Bayridge_bk
#  93        15         23      Bayridge_bk
#  94        16         21      Bayridge_bk
#  95        17         18      Bayridge_bk
#  96        18          9      Bayridge_bk
#  97        19         11      Bayridge_bk
#  98        20         22      Bayridge_bk
#  99        21         11      Bayridge_bk
#  100       22          9      Bayridge_bk
#  101       23          7      Bayridge_bk
#  102       24          8      Bayridge_bk
#  103       25         13      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      14033  upper_manhattan
#  1          1      22967  upper_manhattan
#  2          2      10887  upper_manhattan
#  3          3       5628  upper_manhattan
#  4          4       3272  upper_manhattan
#  5          5       2397  upper_manhattan
#  6          6       1650  upper_manhattan
#  7          7       1479  upper_manhattan
#  8          8        927  upper_manhattan
#  9          9        528  upper_manhattan
#  10        10        291  upper_manhattan
#  11        11        214  upper_manhattan
#  12        12        124  upper_manhattan
#  13        13         97  upper_manhattan
#  14        14         78  upper_manhattan
#  15        15         57  upper_manhattan
#  16        16         69  upper_manhattan
#  17        17        141  upper_manhattan
#  18        18        257  upper_manhattan
#  19        19         56  upper_manhattan
#  20        20         29  upper_manhattan
#  21        21         21  upper_manhattan
#  22        22         12  upper_manhattan
#  23        23          5  upper_manhattan
#  24        24          4  upper_manhattan
#  25        25         25  upper_manhattan
#  26         0          1  lower_manhattan
#  27         1          4  lower_manhattan
#  28         2         23  lower_manhattan
#  29         3         31  lower_manhattan
#  ..       ...        ...              ...
#  74        22         33      Downtown_Bk
#  75        23         31      Downtown_Bk
#  76        24         33      Downtown_Bk
#  77        25        161      Downtown_Bk
#  78         0        624      Bayridge_bk
#  79         1       1149      Bayridge_bk
#  80         2        943      Bayridge_bk
#  81         3        627      Bayridge_bk
#  82         4        358      Bayridge_bk
#  83         5        330      Bayridge_bk
#  84         6        313      Bayridge_bk
#  85         7        278      Bayridge_bk
#  86         8        179      Bayridge_bk
#  87         9        146      Bayridge_bk
#  88        10        130      Bayridge_bk
#  89        11         85      Bayridge_bk
#  90        12         71      Bayridge_bk
#  91        13         65      Bayridge_bk
#  92        14         54      Bayridge_bk
#  93        15         29      Bayridge_bk
#  94        16         14      Bayridge_bk
#  95        17         15      Bayridge_bk
#  96        18          9      Bayridge_bk
#  97        19         14      Bayridge_bk
#  98        20         11      Bayridge_bk
#  99        21          5      Bayridge_bk
#  100       22          4      Bayridge_bk
#  101       23         16      Bayridge_bk
#  102       24          5      Bayridge_bk
#  103       25         14      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      18502  upper_manhattan
#  1          1      28318  upper_manhattan
#  2          2      12534  upper_manhattan
#  3          3       6560  upper_manhattan
#  4          4       3835  upper_manhattan
#  5          5       2730  upper_manhattan
#  6          6       1954  upper_manhattan
#  7          7       1549  upper_manhattan
#  8          8       1000  upper_manhattan
#  9          9        586  upper_manhattan
#  10        10        358  upper_manhattan
#  11        11        237  upper_manhattan
#  12        12        143  upper_manhattan
#  13        13        118  upper_manhattan
#  14        14        103  upper_manhattan
#  15        15         83  upper_manhattan
#  16        16         74  upper_manhattan
#  17        17        163  upper_manhattan
#  18        18        285  upper_manhattan
#  19        19         64  upper_manhattan
#  20        20         27  upper_manhattan
#  21        21         24  upper_manhattan
#  22        22         12  upper_manhattan
#  23        23          7  upper_manhattan
#  24        24          5  upper_manhattan
#  25        25         61  upper_manhattan
#  26         0          3  lower_manhattan
#  27         1          2  lower_manhattan
#  28         2          3  lower_manhattan
#  29         3          2  lower_manhattan
#  ..       ...        ...              ...
#  74        22         45      Downtown_Bk
#  75        23         42      Downtown_Bk
#  76        24         41      Downtown_Bk
#  77        25        219      Downtown_Bk
#  78         0       1234      Bayridge_bk
#  79         1       1822      Bayridge_bk
#  80         2       1251      Bayridge_bk
#  81         3        750      Bayridge_bk
#  82         4        453      Bayridge_bk
#  83         5        343      Bayridge_bk
#  84         6        275      Bayridge_bk
#  85         7        238      Bayridge_bk
#  86         8        189      Bayridge_bk
#  87         9        128      Bayridge_bk
#  88        10        122      Bayridge_bk
#  89        11         71      Bayridge_bk
#  90        12         85      Bayridge_bk
#  91        13         55      Bayridge_bk
#  92        14         50      Bayridge_bk
#  93        15         34      Bayridge_bk
#  94        16         24      Bayridge_bk
#  95        17         18      Bayridge_bk
#  96        18          7      Bayridge_bk
#  97        19          8      Bayridge_bk
#  98        20         11      Bayridge_bk
#  99        21          4      Bayridge_bk
#  100       22          8      Bayridge_bk
#  101       23          6      Bayridge_bk
#  102       24          4      Bayridge_bk
#  103       25         17      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      19202  upper_manhattan
#  1          1      28531  upper_manhattan
#  2          2      12958  upper_manhattan
#  3          3       6619  upper_manhattan
#  4          4       3780  upper_manhattan
#  5          5       2931  upper_manhattan
#  6          6       2162  upper_manhattan
#  7          7       1686  upper_manhattan
#  8          8       1046  upper_manhattan
#  9          9        641  upper_manhattan
#  10        10        354  upper_manhattan
#  11        11        257  upper_manhattan
#  12        12        155  upper_manhattan
#  13        13        128  upper_manhattan
#  14        14         99  upper_manhattan
#  15        15         79  upper_manhattan
#  16        16         68  upper_manhattan
#  17        17        192  upper_manhattan
#  18        18        320  upper_manhattan
#  19        19         86  upper_manhattan
#  20        20         32  upper_manhattan
#  21        21         14  upper_manhattan
#  22        22         20  upper_manhattan
#  23        23         13  upper_manhattan
#  24        24          8  upper_manhattan
#  25        25         60  upper_manhattan
#  26         0          1  lower_manhattan
#  27         1          1  lower_manhattan
#  28         2          4  lower_manhattan
#  29         3          2  lower_manhattan
#  ..       ...        ...              ...
#  74        22         54      Downtown_Bk
#  75        23         49      Downtown_Bk
#  76        24         37      Downtown_Bk
#  77        25        288      Downtown_Bk
#  78         0       1457      Bayridge_bk
#  79         1       2458      Bayridge_bk
#  80         2       1598      Bayridge_bk
#  81         3        952      Bayridge_bk
#  82         4        564      Bayridge_bk
#  83         5        465      Bayridge_bk
#  84         6        358      Bayridge_bk
#  85         7        374      Bayridge_bk
#  86         8        269      Bayridge_bk
#  87         9        218      Bayridge_bk
#  88        10        143      Bayridge_bk
#  89        11        111      Bayridge_bk
#  90        12        108      Bayridge_bk
#  91        13         82      Bayridge_bk
#  92        14         53      Bayridge_bk
#  93        15         37      Bayridge_bk
#  94        16         41      Bayridge_bk
#  95        17         19      Bayridge_bk
#  96        18         27      Bayridge_bk
#  97        19         12      Bayridge_bk
#  98        20         23      Bayridge_bk
#  99        21          8      Bayridge_bk
#  100       22          6      Bayridge_bk
#  101       23         10      Bayridge_bk
#  102       24         12      Bayridge_bk
#  103       25         24      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      19149  upper_manhattan
#  1          1      28465  upper_manhattan
#  2          2      12663  upper_manhattan
#  3          3       6518  upper_manhattan
#  4          4       3763  upper_manhattan
#  5          5       2874  upper_manhattan
#  6          6       1959  upper_manhattan
#  7          7       1605  upper_manhattan
#  8          8        990  upper_manhattan
#  9          9        610  upper_manhattan
#  10        10        357  upper_manhattan
#  11        11        226  upper_manhattan
#  12        12        133  upper_manhattan
#  13        13         94  upper_manhattan
#  14        14         68  upper_manhattan
#  15        15         93  upper_manhattan
#  16        16         64  upper_manhattan
#  17        17        193  upper_manhattan
#  18        18        340  upper_manhattan
#  19        19         68  upper_manhattan
#  20        20         29  upper_manhattan
#  21        21         21  upper_manhattan
#  22        22         11  upper_manhattan
#  23        23          6  upper_manhattan
#  24        24          4  upper_manhattan
#  25        25         58  upper_manhattan
#  26         0          1  lower_manhattan
#  27         1          2  lower_manhattan
#  28         2          4  lower_manhattan
#  29         3          2  lower_manhattan
#  ..       ...        ...              ...
#  74        22         52      Downtown_Bk
#  75        23         37      Downtown_Bk
#  76        24         40      Downtown_Bk
#  77        25        233      Downtown_Bk
#  78         0       1738      Bayridge_bk
#  79         1       2592      Bayridge_bk
#  80         2       1654      Bayridge_bk
#  81         3        988      Bayridge_bk
#  82         4        611      Bayridge_bk
#  83         5        419      Bayridge_bk
#  84         6        375      Bayridge_bk
#  85         7        305      Bayridge_bk
#  86         8        204      Bayridge_bk
#  87         9        183      Bayridge_bk
#  88        10        123      Bayridge_bk
#  89        11         83      Bayridge_bk
#  90        12         80      Bayridge_bk
#  91        13         66      Bayridge_bk
#  92        14         50      Bayridge_bk
#  93        15         33      Bayridge_bk
#  94        16         35      Bayridge_bk
#  95        17         20      Bayridge_bk
#  96        18         11      Bayridge_bk
#  97        19         13      Bayridge_bk
#  98        20         17      Bayridge_bk
#  99        21          8      Bayridge_bk
#  100       22          6      Bayridge_bk
#  101       23          8      Bayridge_bk
#  102       24          7      Bayridge_bk
#  103       25         19      Bayridge_bk
#
#  [104 rows x 3 columns]]
