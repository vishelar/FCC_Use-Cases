# %%
import pandas as pd
import geopandas as gp
from fiona.crs import from_epsg
import shapely
import matplotlib.pylab as plt
import csv
import dateutil
import os
from shapely.geometry import Point
# %matplotlib inline

# %%
# files for each year like:
## <neighborhood/borough of pick up>,<distance>,<ended on Manhattan (0/1)>,<number of trips>.

# %%
def clean_columns(data,year):
    
    data.columns = map(lambda x: x.strip(), list(data.columns))
    data.columns = map(lambda x: x.lower(), list(data.columns))
        
    if (year == '2014') | (year == '2013'):
        data.drop([u'vendor_id', u'passenger_count', u'rate_code', u'store_and_fwd_flag',
                   'dropoff_longitude','dropoff_latitude', u'payment_type',u'fare_amount', 
                   u'surcharge', u'mta_tax', u'tip_amount',
                   u'tolls_amount', u'total_amount'], axis = 1, inplace = True)
        
    elif year == '2015':
        data.drop([u'vendorid', u'passenger_count', u'ratecodeid', u'store_and_fwd_flag',
                   u'dropoff_longitude', u'dropoff_latitude', u'payment_type',
                   u'fare_amount', u'extra', u'mta_tax', u'tip_amount', u'tolls_amount',
                   u'improvement_surcharge', u'total_amount'], axis = 1, inplace = True)
    
    elif year == '2016':    
        data.drop([u'vendorid', u'passenger_count', u'ratecodeid', u'store_and_fwd_flag',
                   u'dropoff_longitude', u'dropoff_latitude', u'payment_type',
                   u'fare_amount', u'extra', u'mta_tax', u'tip_amount', u'tolls_amount',
                   u'improvement_surcharge', u'total_amount'], axis = 1, inplace = True)
    
    data.columns = ['date', 'dropoff_datetime', 'trip_distance', 
                    'pickup_longitude', 'pickup_latitude']
    
    return data

# %%
def segregate(data):
    
    man_upper = [24,151,238,75, 236, 263, 262, 239, 143, 142, 237, 141, 140]
    man_lower = [4, 79,113, 114, 249, 158, 125, 211, 144, 148, 232, 13, 231, 45,209,87,88,12,261]
    bk_dwn = [17,  25,  33, 49,  40,  34, 52, 54, 65, 106, 97, 66, 181, 189, 190, 195]
    bk_br = [11, 14, 22, 26, 67, 111, 227, 228]
    
    groups = range(0,25)
    groups.extend([25,data.trip_distance.max()])
    data['trip_cat'] = pd.cut(data.trip_distance, groups, labels=groups[:-1])
    data_man_upper = data[data.LocationID.isin(man_upper)]
    data_man_lower = data[data.LocationID.isin(man_lower)]
    data_bk_dwn = data[data.LocationID.isin(bk_dwn)]
    data_bk_br = data[data.LocationID.isin(bk_br)]
    
    data_man_upper = data_man_upper.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_man_lower = data_man_lower.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_bk_dwn = data_bk_dwn.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_bk_br = data_bk_br.groupby(['trip_cat']).agg({'LocationID':'count'})
        
    data_man_upper.reset_index(inplace=True)
    data_man_lower.reset_index(inplace=True)
    data_bk_dwn.reset_index(inplace=True)
    data_bk_br.reset_index(inplace=True)
    

    data_man_upper.loc[:, 'neighbourhood'] =  'upper_manhattan'
    data_man_lower.loc[:, 'neighbourhood'] =  'lower_manhattan'
    data_bk_dwn.loc[:, 'neighbourhood'] =  'Downtown_Bk'
    data_bk_br.loc[:, 'neighbourhood'] =  'Bayridge_bk'
    
    data = pd.concat([data_man_upper, data_man_lower, data_bk_dwn, data_bk_br], axis=0, ignore_index=True)
    data.columns = ['trip_cat', 'num_rides', 'neighbourhood']
    
    return data

# %%
def data_aggregator(data, tzone):
    
#     data["date"] = pd.to_datetime(data["date"])

    crs = {'init': 'epsg:4326', 'no_defs': True}
    geometry = [Point(xy) for xy in zip(data["pickup_longitude"], data["pickup_latitude"])]
    data = data.drop(["pickup_longitude", "pickup_latitude"], axis=1)
    data = gp.GeoDataFrame(data, crs=crs, geometry=geometry)

    print "Spatially joining data and taxi zones"
    data_geo = gp.sjoin(tzones, data) 
    data_geo = data_geo[['LocationID','trip_distance']]   
    
    print "Segregating"
    data_agg = segregate(data_geo)
    
    return data_agg

# %%
# Read data by month
def yellow_taxi(tzones): 
    
    
    if not (os.path.isdir("../../Data/Dist_agg")):
        print "Creating Folder Data/Dist_agg"
        os.system("mkdir ../../Data/Dist_agg")
        
#     year = ['2014', '2015']
#     months = ['01','02','03','04','05','06','07','08','09','10','11','12']
#     year = ['2014']
    year = ['2015']
    months = ['03']

    yellow = []
    for y in year:
        for m in months:
            
            print "Reading Data/Yellow/yellow_tripdata_" + y + "-" + m + ".csv"
            data = pd.read_csv("../../Data/Yellow/yellow_tripdata_" + y + "-" + m + ".csv")
            print "Cleaning columns"
            data = clean_columns(data, y)
            print "Aggregating data"
            data_agg = data_aggregator(data, tzones)
            data_agg.to_csv("../../Data/Dist_agg/yellow_"+ y + "-" + m + ".csv")
            print 'Done'
            yellow.append(data_agg)
    
    return yellow

# %%
tzones = gp.read_file("../../Data/taxi_zones/taxi_zones_updated.shp")
tzones.to_crs(epsg=4326, inplace=True)

# %%
data = yellow_taxi(tzones)
# Out:
# Reading Data/Yellow/yellow_tripdata_2015-03.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done

# %%
def clean_columns_green(data,year, month):
    
    data.columns = map(lambda x: x.strip(), list(data.columns))
    data.columns = map(lambda x: x.lower(), list(data.columns))
    
    if (((year == '2015') & (month in ['07', '08', '09', '10', '11', '12'])) | (year == '2016')):
        data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                   u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                   u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                   u'improvement_surcharge', u'total_amount', u'payment_type',
                   u'trip_type'], axis = 1, inplace = True)
    
    else: 
    
        cols = data.columns
        data.reset_index(inplace=True)
        data = data.iloc[:,:len(cols)]
        data.columns = cols
        
        if year == '2015':
            data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                       u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                       u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                       u'improvement_surcharge', u'total_amount', u'payment_type',
                       u'trip_type'], axis = 1, inplace = True)
        
        elif (year == '2014') | (year == '2013'):
            data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                       u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                       u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                       u'total_amount', u'payment_type', u'trip_type'], axis = 1, inplace = True)
               
    data.columns = ['date', 'dropoff_datetime','pickup_longitude', 'pickup_latitude', 
                    'trip_distance']
    
    return data

# Read data by month
def green_taxi(tzones): 
    
    
    if not (os.path.isdir("../../Data/Dist_agg")):
        print "Creating Folder Data/Dist_agg"
        os.system("mkdir ../../Data/Dist_agg")
        
#     year = ['2014', '2015']
#     months = ['01','02','03','04','05','06','07','08','09','10','11','12']
    year = ['2014', '2015']
    months = ['01','02','03']

    green = []
    for y in year:
        for m in months:
            
            print "Reading Data/Green/green_tripdata_" + y + "-" + m + ".csv"
            data = pd.read_csv("../../Data/Green/green_tripdata_" + y + "-" + m + ".csv")
            print "Cleaning columns"
            data = clean_columns_green(data, y, m)
            print "Aggregating data"
            data_agg = data_aggregator(data, tzones)
            data_agg.to_csv("../../Data/Dist_agg/green_"+ y + "-" + m + ".csv")
            print 'Done'
            green.append(data_agg)
    
    return green

# %%
green_taxien_taxi(tzones)
# Out:
# Reading Data/Green/green_tripdata_2014-01.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2014-02.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2014-03.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-01.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-02.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-03.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# [    trip_cat  num_rides    neighbourhood
#  0          0      11254  upper_manhattan
#  1          1      17077  upper_manhattan
#  2          2       7846  upper_manhattan
#  3          3       3898  upper_manhattan
#  4          4       2338  upper_manhattan
#  5          5       1787  upper_manhattan
#  6          6       1252  upper_manhattan
#  7          7        950  upper_manhattan
#  8          8        588  upper_manhattan
#  9          9        368  upper_manhattan
#  10        10        213  upper_manhattan
#  11        11        137  upper_manhattan
#  12        12         89  upper_manhattan
#  13        13         44  upper_manhattan
#  14        14         45  upper_manhattan
#  15        15         45  upper_manhattan
#  16        16         42  upper_manhattan
#  17        17         86  upper_manhattan
#  18        18        150  upper_manhattan
#  19        19         41  upper_manhattan
#  20        20         24  upper_manhattan
#  21        21          8  upper_manhattan
#  22        22         10  upper_manhattan
#  23        23          9  upper_manhattan
#  24        24          2  upper_manhattan
#  25        25         18  upper_manhattan
#  26         0          6  lower_manhattan
#  27         1          6  lower_manhattan
#  28         2         10  lower_manhattan
#  29         3          8  lower_manhattan
#  ..       ...        ...              ...
#  74        22          7      Downtown_Bk
#  75        23         12      Downtown_Bk
#  76        24          7      Downtown_Bk
#  77        25         71      Downtown_Bk
#  78         0        234      Bayridge_bk
#  79         1        358      Bayridge_bk
#  80         2        261      Bayridge_bk
#  81         3        143      Bayridge_bk
#  82         4         89      Bayridge_bk
#  83         5         91      Bayridge_bk
#  84         6         71      Bayridge_bk
#  85         7         62      Bayridge_bk
#  86         8         68      Bayridge_bk
#  87         9         40      Bayridge_bk
#  88        10         36      Bayridge_bk
#  89        11         32      Bayridge_bk
#  90        12         21      Bayridge_bk
#  91        13         13      Bayridge_bk
#  92        14         11      Bayridge_bk
#  93        15          6      Bayridge_bk
#  94        16         10      Bayridge_bk
#  95        17          3      Bayridge_bk
#  96        18          1      Bayridge_bk
#  97        19          4      Bayridge_bk
#  98        20          5      Bayridge_bk
#  99        21          2      Bayridge_bk
#  100       22          1      Bayridge_bk
#  101       23          2      Bayridge_bk
#  102       24          0      Bayridge_bk
#  103       25          4      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      12597  upper_manhattan
#  1          1      18833  upper_manhattan
#  2          2       8681  upper_manhattan
#  3          3       4295  upper_manhattan
#  4          4       2587  upper_manhattan
#  5          5       1970  upper_manhattan
#  6          6       1401  upper_manhattan
#  7          7       1096  upper_manhattan
#  8          8        707  upper_manhattan
#  9          9        414  upper_manhattan
#  10        10        218  upper_manhattan
#  11        11        139  upper_manhattan
#  12        12         89  upper_manhattan
#  13        13         68  upper_manhattan
#  14        14         50  upper_manhattan
#  15        15         42  upper_manhattan
#  16        16         33  upper_manhattan
#  17        17         94  upper_manhattan
#  18        18        157  upper_manhattan
#  19        19         33  upper_manhattan
#  20        20         12  upper_manhattan
#  21        21          8  upper_manhattan
#  22        22          9  upper_manhattan
#  23        23          4  upper_manhattan
#  24        24          3  upper_manhattan
#  25        25         23  upper_manhattan
#  26         0          9  lower_manhattan
#  27         1         17  lower_manhattan
#  28         2         13  lower_manhattan
#  29         3         20  lower_manhattan
#  ..       ...        ...              ...
#  74        22         18      Downtown_Bk
#  75        23          7      Downtown_Bk
#  76        24         14      Downtown_Bk
#  77        25         87      Downtown_Bk
#  78         0        326      Bayridge_bk
#  79         1        479      Bayridge_bk
#  80         2        366      Bayridge_bk
#  81         3        222      Bayridge_bk
#  82         4        165      Bayridge_bk
#  83         5        116      Bayridge_bk
#  84         6        104      Bayridge_bk
#  85         7         95      Bayridge_bk
#  86         8         82      Bayridge_bk
#  87         9         64      Bayridge_bk
#  88        10         56      Bayridge_bk
#  89        11         32      Bayridge_bk
#  90        12         15      Bayridge_bk
#  91        13         19      Bayridge_bk
#  92        14         18      Bayridge_bk
#  93        15          7      Bayridge_bk
#  94        16          7      Bayridge_bk
#  95        17         13      Bayridge_bk
#  96        18          3      Bayridge_bk
#  97        19          2      Bayridge_bk
#  98        20          3      Bayridge_bk
#  99        21          4      Bayridge_bk
#  100       22          2      Bayridge_bk
#  101       23          3      Bayridge_bk
#  102       24          0      Bayridge_bk
#  103       25          5      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      15913  upper_manhattan
#  1          1      24096  upper_manhattan
#  2          2      11041  upper_manhattan
#  3          3       5826  upper_manhattan
#  4          4       3562  upper_manhattan
#  5          5       2686  upper_manhattan
#  6          6       1773  upper_manhattan
#  7          7       1447  upper_manhattan
#  8          8        967  upper_manhattan
#  9          9        534  upper_manhattan
#  10        10        324  upper_manhattan
#  11        11        203  upper_manhattan
#  12        12        127  upper_manhattan
#  13        13         93  upper_manhattan
#  14        14         84  upper_manhattan
#  15        15         71  upper_manhattan
#  16        16         54  upper_manhattan
#  17        17        134  upper_manhattan
#  18        18        190  upper_manhattan
#  19        19         47  upper_manhattan
#  20        20         25  upper_manhattan
#  21        21         20  upper_manhattan
#  22        22         11  upper_manhattan
#  23        23          8  upper_manhattan
#  24        24          6  upper_manhattan
#  25        25         30  upper_manhattan
#  26         0          4  lower_manhattan
#  27         1          6  lower_manhattan
#  28         2          9  lower_manhattan
#  29         3         14  lower_manhattan
#  ..       ...        ...              ...
#  74        22         36      Downtown_Bk
#  75        23         22      Downtown_Bk
#  76        24         25      Downtown_Bk
#  77        25        119      Downtown_Bk
#  78         0        522      Bayridge_bk
#  79         1        754      Bayridge_bk
#  80         2        550      Bayridge_bk
#  81         3        363      Bayridge_bk
#  82         4        231      Bayridge_bk
#  83         5        199      Bayridge_bk
#  84         6        153      Bayridge_bk
#  85         7        146      Bayridge_bk
#  86         8        120      Bayridge_bk
#  87         9         85      Bayridge_bk
#  88        10         73      Bayridge_bk
#  89        11         43      Bayridge_bk
#  90        12         33      Bayridge_bk
#  91        13         24      Bayridge_bk
#  92        14         25      Bayridge_bk
#  93        15         17      Bayridge_bk
#  94        16         14      Bayridge_bk
#  95        17         11      Bayridge_bk
#  96        18          6      Bayridge_bk
#  97        19          9      Bayridge_bk
#  98        20          7      Bayridge_bk
#  99        21          7      Bayridge_bk
#  100       22          3      Bayridge_bk
#  101       23          4      Bayridge_bk
#  102       24          0      Bayridge_bk
#  103       25          6      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      19772  upper_manhattan
#  1          1      27929  upper_manhattan
#  2          2      12171  upper_manhattan
#  3          3       6107  upper_manhattan
#  4          4       3479  upper_manhattan
#  5          5       2615  upper_manhattan
#  6          6       1864  upper_manhattan
#  7          7       1428  upper_manhattan
#  8          8        866  upper_manhattan
#  9          9        504  upper_manhattan
#  10        10        292  upper_manhattan
#  11        11        223  upper_manhattan
#  12        12        122  upper_manhattan
#  13        13         89  upper_manhattan
#  14        14         78  upper_manhattan
#  15        15         61  upper_manhattan
#  16        16         50  upper_manhattan
#  17        17        124  upper_manhattan
#  18        18        212  upper_manhattan
#  19        19         59  upper_manhattan
#  20        20         28  upper_manhattan
#  21        21         14  upper_manhattan
#  22        22         11  upper_manhattan
#  23        23          9  upper_manhattan
#  24        24          5  upper_manhattan
#  25        25         55  upper_manhattan
#  26         0          2  lower_manhattan
#  27         1          2  lower_manhattan
#  28         2          3  lower_manhattan
#  29         3          4  lower_manhattan
#  ..       ...        ...              ...
#  74        22         42      Downtown_Bk
#  75        23         32      Downtown_Bk
#  76        24         21      Downtown_Bk
#  77        25        180      Downtown_Bk
#  78         0        980      Bayridge_bk
#  79         1       1431      Bayridge_bk
#  80         2        907      Bayridge_bk
#  81         3        598      Bayridge_bk
#  82         4        369      Bayridge_bk
#  83         5        264      Bayridge_bk
#  84         6        211      Bayridge_bk
#  85         7        178      Bayridge_bk
#  86         8        143      Bayridge_bk
#  87         9        119      Bayridge_bk
#  88        10         83      Bayridge_bk
#  89        11         57      Bayridge_bk
#  90        12         46      Bayridge_bk
#  91        13         44      Bayridge_bk
#  92        14         28      Bayridge_bk
#  93        15         14      Bayridge_bk
#  94        16         18      Bayridge_bk
#  95        17         16      Bayridge_bk
#  96        18          7      Bayridge_bk
#  97        19         18      Bayridge_bk
#  98        20          9      Bayridge_bk
#  99        21          7      Bayridge_bk
#  100       22         10      Bayridge_bk
#  101       23          8      Bayridge_bk
#  102       24          5      Bayridge_bk
#  103       25          7      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      19149  upper_manhattan
#  1          1      26942  upper_manhattan
#  2          2      11660  upper_manhattan
#  3          3       5618  upper_manhattan
#  4          4       3355  upper_manhattan
#  5          5       2489  upper_manhattan
#  6          6       1867  upper_manhattan
#  7          7       1409  upper_manhattan
#  8          8        869  upper_manhattan
#  9          9        544  upper_manhattan
#  10        10        348  upper_manhattan
#  11        11        216  upper_manhattan
#  12        12        105  upper_manhattan
#  13        13         91  upper_manhattan
#  14        14         86  upper_manhattan
#  15        15         57  upper_manhattan
#  16        16         58  upper_manhattan
#  17        17        130  upper_manhattan
#  18        18        227  upper_manhattan
#  19        19         52  upper_manhattan
#  20        20         26  upper_manhattan
#  21        21         21  upper_manhattan
#  22        22          8  upper_manhattan
#  23        23          6  upper_manhattan
#  24        24          9  upper_manhattan
#  25        25         41  upper_manhattan
#  26         0          9  lower_manhattan
#  27         1          4  lower_manhattan
#  28         2          1  lower_manhattan
#  29         3          6  lower_manhattan
#  ..       ...        ...              ...
#  74        22         32      Downtown_Bk
#  75        23         34      Downtown_Bk
#  76        24         35      Downtown_Bk
#  77        25        190      Downtown_Bk
#  78         0       1073      Bayridge_bk
#  79         1       1490      Bayridge_bk
#  80         2       1001      Bayridge_bk
#  81         3        597      Bayridge_bk
#  82         4        353      Bayridge_bk
#  83         5        289      Bayridge_bk
#  84         6        246      Bayridge_bk
#  85         7        213      Bayridge_bk
#  86         8        139      Bayridge_bk
#  87         9        160      Bayridge_bk
#  88        10        117      Bayridge_bk
#  89        11         60      Bayridge_bk
#  90        12         70      Bayridge_bk
#  91        13         47      Bayridge_bk
#  92        14         39      Bayridge_bk
#  93        15         29      Bayridge_bk
#  94        16         14      Bayridge_bk
#  95        17         18      Bayridge_bk
#  96        18         12      Bayridge_bk
#  97        19         11      Bayridge_bk
#  98        20         14      Bayridge_bk
#  99        21          5      Bayridge_bk
#  100       22         13      Bayridge_bk
#  101       23          6      Bayridge_bk
#  102       24          7      Bayridge_bk
#  103       25         20      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      19404  upper_manhattan
#  1          1      28583  upper_manhattan
#  2          2      12833  upper_manhattan
#  3          3       6354  upper_manhattan
#  4          4       3771  upper_manhattan
#  5          5       2798  upper_manhattan
#  6          6       1920  upper_manhattan
#  7          7       1540  upper_manhattan
#  8          8        989  upper_manhattan
#  9          9        572  upper_manhattan
#  10        10        351  upper_manhattan
#  11        11        221  upper_manhattan
#  12        12        126  upper_manhattan
#  13        13        103  upper_manhattan
#  14        14         87  upper_manhattan
#  15        15         71  upper_manhattan
#  16        16         63  upper_manhattan
#  17        17        122  upper_manhattan
#  18        18        301  upper_manhattan
#  19        19         57  upper_manhattan
#  20        20         19  upper_manhattan
#  21        21         11  upper_manhattan
#  22        22          8  upper_manhattan
#  23        23          5  upper_manhattan
#  24        24          5  upper_manhattan
#  25        25         44  upper_manhattan
#  26         0          6  lower_manhattan
#  27         1          1  lower_manhattan
#  28         2          7  lower_manhattan
#  29         3          1  lower_manhattan
#  ..       ...        ...              ...
#  74        22         59      Downtown_Bk
#  75        23         44      Downtown_Bk
#  76        24         43      Downtown_Bk
#  77        25        231      Downtown_Bk
#  78         0       1311      Bayridge_bk
#  79         1       1998      Bayridge_bk
#  80         2       1317      Bayridge_bk
#  81         3        763      Bayridge_bk
#  82         4        489      Bayridge_bk
#  83         5        399      Bayridge_bk
#  84         6        332      Bayridge_bk
#  85         7        263      Bayridge_bk
#  86         8        186      Bayridge_bk
#  87         9        161      Bayridge_bk
#  88        10        125      Bayridge_bk
#  89        11         94      Bayridge_bk
#  90        12         77      Bayridge_bk
#  91        13         61      Bayridge_bk
#  92        14         56      Bayridge_bk
#  93        15         31      Bayridge_bk
#  94        16         24      Bayridge_bk
#  95        17         16      Bayridge_bk
#  96        18         14      Bayridge_bk
#  97        19         15      Bayridge_bk
#  98        20          9      Bayridge_bk
#  99        21          4      Bayridge_bk
#  100       22          8      Bayridge_bk
#  101       23          7      Bayridge_bk
#  102       24         11      Bayridge_bk
#  103       25         16      Bayridge_bk
#
#  [104 rows x 3 columns]]
