# %%
import pandas as pd
import geopandas as gp
from fiona.crs import from_epsg
import shapely
import matplotlib.pylab as plt
import csv
import dateutil
import os
from shapely.geometry import Point
# %matplotlib inline

# %%
# files for each year like:
## <neighborhood/borough of pick up>,<distance>,<ended on Manhattan (0/1)>,<number of trips>.

# %%
def clean_columns(data,year):
    
    data.columns = map(lambda x: x.strip(), list(data.columns))
    data.columns = map(lambda x: x.lower(), list(data.columns))
        
    if (year == '2014') | (year == '2013'):
        data.drop([u'vendor_id', u'passenger_count', u'rate_code', u'store_and_fwd_flag',
                   'dropoff_longitude','dropoff_latitude', u'payment_type',u'fare_amount', 
                   u'surcharge', u'mta_tax', u'tip_amount',
                   u'tolls_amount', u'total_amount'], axis = 1, inplace = True)
        
    elif year == '2015':
        data.drop([u'vendorid', u'passenger_count', u'ratecodeid', u'store_and_fwd_flag',
                   u'dropoff_longitude', u'dropoff_latitude', u'payment_type',
                   u'fare_amount', u'extra', u'mta_tax', u'tip_amount', u'tolls_amount',
                   u'improvement_surcharge', u'total_amount'], axis = 1, inplace = True)
    
    elif year == '2016':    
        data.drop([u'vendorid', u'passenger_count', u'ratecodeid', u'store_and_fwd_flag',
                   u'dropoff_longitude', u'dropoff_latitude', u'payment_type',
                   u'fare_amount', u'extra', u'mta_tax', u'tip_amount', u'tolls_amount',
                   u'improvement_surcharge', u'total_amount'], axis = 1, inplace = True)
    
    data.columns = ['date', 'dropoff_datetime', 'trip_distance', 
                    'pickup_longitude', 'pickup_latitude']
    
    return data

# %%
def segregate(data):
    
    man_upper = [24,151,238,75, 236, 263, 262, 239, 143, 142, 237, 141, 140]
    man_lower = [4, 79,113, 114, 249, 158, 125, 211, 144, 148, 232, 13, 231, 45,209,87,88,12,261]
    bk_dwn = [17,  25,  33, 49,  40,  34, 52, 54, 65, 106, 97, 66, 181, 189, 190, 195]
    bk_br = [11, 14, 22, 26, 67, 111, 227, 228]
    
    groups = range(0,25)
    groups.extend([25,data.trip_distance.max()])
    data['trip_cat'] = pd.cut(data.trip_distance, groups, labels=groups[:-1])
    data_man_upper = data[data.LocationID.isin(man_upper)]
    data_man_lower = data[data.LocationID.isin(man_lower)]
    data_bk_dwn = data[data.LocationID.isin(bk_dwn)]
    data_bk_br = data[data.LocationID.isin(bk_br)]
    
    data_man_upper = data_man_upper.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_man_lower = data_man_lower.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_bk_dwn = data_bk_dwn.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_bk_br = data_bk_br.groupby(['trip_cat']).agg({'LocationID':'count'})
        
    data_man_upper.reset_index(inplace=True)
    data_man_lower.reset_index(inplace=True)
    data_bk_dwn.reset_index(inplace=True)
    data_bk_br.reset_index(inplace=True)
    

    data_man_upper.loc[:, 'neighbourhood'] =  'upper_manhattan'
    data_man_lower.loc[:, 'neighbourhood'] =  'lower_manhattan'
    data_bk_dwn.loc[:, 'neighbourhood'] =  'Downtown_Bk'
    data_bk_br.loc[:, 'neighbourhood'] =  'Bayridge_bk'
    
    data = pd.concat([data_man_upper, data_man_lower, data_bk_dwn, data_bk_br], axis=0, ignore_index=True)
    data.columns = ['trip_cat', 'num_rides', 'neighbourhood']
    
    return data

# %%
def data_aggregator(data, tzone):
    
#     data["date"] = pd.to_datetime(data["date"])

    crs = {'init': 'epsg:4326', 'no_defs': True}
    geometry = [Point(xy) for xy in zip(data["pickup_longitude"], data["pickup_latitude"])]
    data = data.drop(["pickup_longitude", "pickup_latitude"], axis=1)
    data = gp.GeoDataFrame(data, crs=crs, geometry=geometry)

    print "Spatially joining data and taxi zones"
    data_geo = gp.sjoin(tzones, data) 
    data_geo = data_geo[['LocationID','trip_distance']]   
    
    print "Segregating"
    data_agg = segregate(data_geo)
    
    return data_agg

# %%
# Read data by month
def yellow_taxi(tzones): 
    
    
    if not (os.path.isdir("../../Data/Dist_agg")):
        print "Creating Folder Data/Dist_agg"
        os.system("mkdir ../../Data/Dist_agg")
        
#     year = ['2014', '2015']
#     months = ['01','02','03','04','05','06','07','08','09','10','11','12']
    year = ['2015']
#     months = ['10','11','12']
    months = ['12']

    yellow = []
    for y in year:
        for m in months:
            
            print "Reading Data/Yellow/yellow_tripdata_" + y + "-" + m + ".csv"
            data = pd.read_csv("../../Data/Yellow/yellow_tripdata_" + y + "-" + m + ".csv")
            print "Cleaning columns"
            data = clean_columns(data, y)
            print "Aggregating data"
            data_agg = data_aggregator(data, tzones)
            data_agg.to_csv("../../Data/Dist_agg/yellow_"+ y + "-" + m + ".csv")
            print 'Done'
            yellow.append(data_agg)
    
    return yellow

# %%
tzones = gp.read_file("../../Data/taxi_zones/taxi_zones_updated.shp")
tzones.to_crs(epsg=4326, inplace=True)

# %%
data = yellow_taxi(tzones)
# Out:
# Reading Data/Yellow/yellow_tripdata_2015-12.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done

# %%
def clean_columns_green(data,year, month):
    
    data.columns = map(lambda x: x.strip(), list(data.columns))
    data.columns = map(lambda x: x.lower(), list(data.columns))
    
    if (((year == '2015') & (month in ['07', '08', '09', '10', '11', '12'])) | (year == '2016')):
        data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                   u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                   u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                   u'improvement_surcharge', u'total_amount', u'payment_type',
                   u'trip_type'], axis = 1, inplace = True)
    
    else: 
    
        cols = data.columns
        data.reset_index(inplace=True)
        data = data.iloc[:,:len(cols)]
        data.columns = cols
        
        if year == '2015':
            data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                       u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                       u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                       u'improvement_surcharge', u'total_amount', u'payment_type',
                       u'trip_type'], axis = 1, inplace = True)
        
        elif (year == '2014') | (year == '2013'):
            data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                       u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                       u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                       u'total_amount', u'payment_type', u'trip_type'], axis = 1, inplace = True)
               
    data.columns = ['date', 'dropoff_datetime','pickup_longitude', 'pickup_latitude', 
                    'trip_distance']
    
    return data

# %%
# Read data by month
def green_taxi(tzones): 
    
    
    if not (os.path.isdir("../../Data/Dist_agg")):
        print "Creating Folder Data/Dist_agg"
        os.system("mkdir ../../Data/Dist_agg")
        
#     year = ['2014', '2015']
#     months = ['01','02','03','04','05','06','07','08','09','10','11','12']
    year = ['2014', '2015']
    months = ['10','11','12']

    green = []
    for y in year:
        for m in months:
            
            print "Reading Data/Green/green_tripdata_" + y + "-" + m + ".csv"
            data = pd.read_csv("../../Data/Green/green_tripdata_" + y + "-" + m + ".csv")
            print "Cleaning columns"
            data = clean_columns_green(data, y, m)
            print "Aggregating data"
            data_agg = data_aggregator(data, tzones)
            data_agg.to_csv("../../Data/Dist_agg/green_"+ y + "-" + m + ".csv")
            print 'Done'
            green.append(data_agg)
    
    return green

# %%
green_taxi(tzones)
# Out:
# Reading Data/Green/green_tripdata_2014-10.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2014-11.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2014-12.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-10.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-11.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-12.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# [    trip_cat  num_rides    neighbourhood
#  0          0        136  upper_manhattan
#  1          1        170  upper_manhattan
#  2          2        104  upper_manhattan
#  3          3         44  upper_manhattan
#  4          4         24  upper_manhattan
#  5          5         16  upper_manhattan
#  6          6         12  upper_manhattan
#  7          7          8  upper_manhattan
#  8          8          4  upper_manhattan
#  9          9          4  upper_manhattan
#  10        10          2  upper_manhattan
#  11        11          0  upper_manhattan
#  12        12          1  upper_manhattan
#  13        13          0  upper_manhattan
#  14        14          0  upper_manhattan
#  15        15          0  upper_manhattan
#  16        16          0  upper_manhattan
#  17        17          1  upper_manhattan
#  18        18          1  upper_manhattan
#  19        19          0  upper_manhattan
#  20        20          0  upper_manhattan
#  21        21          0  upper_manhattan
#  22        22          0  upper_manhattan
#  23        23          0  upper_manhattan
#  24        24          0  upper_manhattan
#  25        25          1  upper_manhattan
#  26         0          0  lower_manhattan
#  27         1          0  lower_manhattan
#  28         2          0  lower_manhattan
#  29         3          0  lower_manhattan
#  ..       ...        ...              ...
#  74        22          0      Downtown_Bk
#  75        23          0      Downtown_Bk
#  76        24          0      Downtown_Bk
#  77        25          2      Downtown_Bk
#  78         0          7      Bayridge_bk
#  79         1          7      Bayridge_bk
#  80         2          7      Bayridge_bk
#  81         3          5      Bayridge_bk
#  82         4          1      Bayridge_bk
#  83         5          1      Bayridge_bk
#  84         6          0      Bayridge_bk
#  85         7          0      Bayridge_bk
#  86         8          0      Bayridge_bk
#  87         9          0      Bayridge_bk
#  88        10          1      Bayridge_bk
#  89        11          2      Bayridge_bk
#  90        12          1      Bayridge_bk
#  91        13          2      Bayridge_bk
#  92        14          0      Bayridge_bk
#  93        15          0      Bayridge_bk
#  94        16          0      Bayridge_bk
#  95        17          0      Bayridge_bk
#  96        18          0      Bayridge_bk
#  97        19          0      Bayridge_bk
#  98        20          0      Bayridge_bk
#  99        21          0      Bayridge_bk
#  100       22          0      Bayridge_bk
#  101       23          0      Bayridge_bk
#  102       24          0      Bayridge_bk
#  103       25          0      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0         37  upper_manhattan
#  1          1         66  upper_manhattan
#  2          2         29  upper_manhattan
#  3          3         25  upper_manhattan
#  4          4         15  upper_manhattan
#  5          5         21  upper_manhattan
#  6          6         12  upper_manhattan
#  7          7         10  upper_manhattan
#  8          8          3  upper_manhattan
#  9          9          7  upper_manhattan
#  10        10          1  upper_manhattan
#  11        11          2  upper_manhattan
#  12        12          2  upper_manhattan
#  13        13          0  upper_manhattan
#  14        14          0  upper_manhattan
#  15        15          1  upper_manhattan
#  16        16          1  upper_manhattan
#  17        17          0  upper_manhattan
#  18        18          0  upper_manhattan
#  19        19          0  upper_manhattan
#  20        20          0  upper_manhattan
#  21        21          0  upper_manhattan
#  22        22          0  upper_manhattan
#  23        23          0  upper_manhattan
#  24        24          0  upper_manhattan
#  25        25          0  upper_manhattan
#  26         0          0  lower_manhattan
#  27         1          0  lower_manhattan
#  28         2          0  lower_manhattan
#  29         3          0  lower_manhattan
#  ..       ...        ...              ...
#  74        22          1      Downtown_Bk
#  75        23          0      Downtown_Bk
#  76        24          0      Downtown_Bk
#  77        25          1      Downtown_Bk
#  78         0          9      Bayridge_bk
#  79         1         12      Bayridge_bk
#  80         2         13      Bayridge_bk
#  81         3          9      Bayridge_bk
#  82         4          9      Bayridge_bk
#  83         5          5      Bayridge_bk
#  84         6          6      Bayridge_bk
#  85         7          9      Bayridge_bk
#  86         8          8      Bayridge_bk
#  87         9          4      Bayridge_bk
#  88        10          2      Bayridge_bk
#  89        11          1      Bayridge_bk
#  90        12          2      Bayridge_bk
#  91        13          2      Bayridge_bk
#  92        14          1      Bayridge_bk
#  93        15          0      Bayridge_bk
#  94        16          0      Bayridge_bk
#  95        17          0      Bayridge_bk
#  96        18          0      Bayridge_bk
#  97        19          0      Bayridge_bk
#  98        20          0      Bayridge_bk
#  99        21          0      Bayridge_bk
#  100       22          0      Bayridge_bk
#  101       23          0      Bayridge_bk
#  102       24          0      Bayridge_bk
#  103       25          0      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0        134  upper_manhattan
#  1          1        159  upper_manhattan
#  2          2         85  upper_manhattan
#  3          3         38  upper_manhattan
#  4          4         24  upper_manhattan
#  5          5         15  upper_manhattan
#  6          6         12  upper_manhattan
#  7          7         15  upper_manhattan
#  8          8         13  upper_manhattan
#  9          9          7  upper_manhattan
#  10        10          2  upper_manhattan
#  11        11          0  upper_manhattan
#  12        12          1  upper_manhattan
#  13        13          1  upper_manhattan
#  14        14          0  upper_manhattan
#  15        15          1  upper_manhattan
#  16        16          0  upper_manhattan
#  17        17          1  upper_manhattan
#  18        18          7  upper_manhattan
#  19        19          0  upper_manhattan
#  20        20          0  upper_manhattan
#  21        21          0  upper_manhattan
#  22        22          0  upper_manhattan
#  23        23          0  upper_manhattan
#  24        24          0  upper_manhattan
#  25        25          0  upper_manhattan
#  26         0          0  lower_manhattan
#  27         1          0  lower_manhattan
#  28         2          0  lower_manhattan
#  29         3          0  lower_manhattan
#  ..       ...        ...              ...
#  74        22          0      Downtown_Bk
#  75        23          0      Downtown_Bk
#  76        24          0      Downtown_Bk
#  77        25          1      Downtown_Bk
#  78         0          4      Bayridge_bk
#  79         1          2      Bayridge_bk
#  80         2          2      Bayridge_bk
#  81         3          5      Bayridge_bk
#  82         4          4      Bayridge_bk
#  83         5          2      Bayridge_bk
#  84         6          0      Bayridge_bk
#  85         7          3      Bayridge_bk
#  86         8          2      Bayridge_bk
#  87         9          0      Bayridge_bk
#  88        10          1      Bayridge_bk
#  89        11          1      Bayridge_bk
#  90        12          0      Bayridge_bk
#  91        13          0      Bayridge_bk
#  92        14          0      Bayridge_bk
#  93        15          0      Bayridge_bk
#  94        16          0      Bayridge_bk
#  95        17          0      Bayridge_bk
#  96        18          0      Bayridge_bk
#  97        19          0      Bayridge_bk
#  98        20          0      Bayridge_bk
#  99        21          0      Bayridge_bk
#  100       22          0      Bayridge_bk
#  101       23          0      Bayridge_bk
#  102       24          0      Bayridge_bk
#  103       25          0      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0        123  upper_manhattan
#  1          1        167  upper_manhattan
#  2          2         90  upper_manhattan
#  3          3         39  upper_manhattan
#  4          4         25  upper_manhattan
#  5          5         15  upper_manhattan
#  6          6          8  upper_manhattan
#  7          7         13  upper_manhattan
#  8          8          1  upper_manhattan
#  9          9          7  upper_manhattan
#  10        10          1  upper_manhattan
#  11        11          0  upper_manhattan
#  12        12          0  upper_manhattan
#  13        13          0  upper_manhattan
#  14        14          0  upper_manhattan
#  15        15          1  upper_manhattan
#  16        16          0  upper_manhattan
#  17        17          2  upper_manhattan
#  18        18          1  upper_manhattan
#  19        19          0  upper_manhattan
#  20        20          1  upper_manhattan
#  21        21          0  upper_manhattan
#  22        22          0  upper_manhattan
#  23        23          0  upper_manhattan
#  24        24          0  upper_manhattan
#  25        25          1  upper_manhattan
#  26         0          0  lower_manhattan
#  27         1          0  lower_manhattan
#  28         2          0  lower_manhattan
#  29         3          0  lower_manhattan
#  ..       ...        ...              ...
#  74        22          0      Downtown_Bk
#  75        23          1      Downtown_Bk
#  76        24          1      Downtown_Bk
#  77        25          4      Downtown_Bk
#  78         0          7      Bayridge_bk
#  79         1         10      Bayridge_bk
#  80         2          2      Bayridge_bk
#  81         3          1      Bayridge_bk
#  82         4          2      Bayridge_bk
#  83         5          3      Bayridge_bk
#  84         6          1      Bayridge_bk
#  85         7          3      Bayridge_bk
#  86         8          0      Bayridge_bk
#  87         9          2      Bayridge_bk
#  88        10          1      Bayridge_bk
#  89        11          1      Bayridge_bk
#  90        12          0      Bayridge_bk
#  91        13          0      Bayridge_bk
#  92        14          0      Bayridge_bk
#  93        15          0      Bayridge_bk
#  94        16          0      Bayridge_bk
#  95        17          0      Bayridge_bk
#  96        18          0      Bayridge_bk
#  97        19          1      Bayridge_bk
#  98        20          0      Bayridge_bk
#  99        21          0      Bayridge_bk
#  100       22          0      Bayridge_bk
#  101       23          0      Bayridge_bk
#  102       24          0      Bayridge_bk
#  103       25          0      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0         42  upper_manhattan
#  1          1         52  upper_manhattan
#  2          2         39  upper_manhattan
#  3          3         25  upper_manhattan
#  4          4         19  upper_manhattan
#  5          5         16  upper_manhattan
#  6          6         13  upper_manhattan
#  7          7          6  upper_manhattan
#  8          8          1  upper_manhattan
#  9          9          0  upper_manhattan
#  10        10          2  upper_manhattan
#  11        11          1  upper_manhattan
#  12        12          0  upper_manhattan
#  13        13          0  upper_manhattan
#  14        14          0  upper_manhattan
#  15        15          0  upper_manhattan
#  16        16          1  upper_manhattan
#  17        17          1  upper_manhattan
#  18        18          0  upper_manhattan
#  19        19          0  upper_manhattan
#  20        20          0  upper_manhattan
#  21        21          0  upper_manhattan
#  22        22          1  upper_manhattan
#  23        23          0  upper_manhattan
#  24        24          0  upper_manhattan
#  25        25          0  upper_manhattan
#  26         0          0  lower_manhattan
#  27         1          0  lower_manhattan
#  28         2          0  lower_manhattan
#  29         3          0  lower_manhattan
#  ..       ...        ...              ...
#  74        22          0      Downtown_Bk
#  75        23          0      Downtown_Bk
#  76        24          0      Downtown_Bk
#  77        25          0      Downtown_Bk
#  78         0          6      Bayridge_bk
#  79         1         12      Bayridge_bk
#  80         2         11      Bayridge_bk
#  81         3          5      Bayridge_bk
#  82         4          3      Bayridge_bk
#  83         5          7      Bayridge_bk
#  84         6          5      Bayridge_bk
#  85         7          4      Bayridge_bk
#  86         8          4      Bayridge_bk
#  87         9          4      Bayridge_bk
#  88        10          2      Bayridge_bk
#  89        11          1      Bayridge_bk
#  90        12          1      Bayridge_bk
#  91        13          1      Bayridge_bk
#  92        14          1      Bayridge_bk
#  93        15          0      Bayridge_bk
#  94        16          0      Bayridge_bk
#  95        17          0      Bayridge_bk
#  96        18          0      Bayridge_bk
#  97        19          0      Bayridge_bk
#  98        20          0      Bayridge_bk
#  99        21          0      Bayridge_bk
#  100       22          0      Bayridge_bk
#  101       23          0      Bayridge_bk
#  102       24          0      Bayridge_bk
#  103       25          0      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0        125  upper_manhattan
#  1          1        206  upper_manhattan
#  2          2        101  upper_manhattan
#  3          3         42  upper_manhattan
#  4          4         22  upper_manhattan
#  5          5         11  upper_manhattan
#  6          6         11  upper_manhattan
#  7          7         19  upper_manhattan
#  8          8         10  upper_manhattan
#  9          9          7  upper_manhattan
#  10        10          3  upper_manhattan
#  11        11          3  upper_manhattan
#  12        12          1  upper_manhattan
#  13        13          1  upper_manhattan
#  14        14          0  upper_manhattan
#  15        15          1  upper_manhattan
#  16        16          0  upper_manhattan
#  17        17          3  upper_manhattan
#  18        18          0  upper_manhattan
#  19        19          0  upper_manhattan
#  20        20          0  upper_manhattan
#  21        21          0  upper_manhattan
#  22        22          0  upper_manhattan
#  23        23          0  upper_manhattan
#  24        24          0  upper_manhattan
#  25        25          2  upper_manhattan
#  26         0          0  lower_manhattan
#  27         1          0  lower_manhattan
#  28         2          0  lower_manhattan
#  29         3          0  lower_manhattan
#  ..       ...        ...              ...
#  74        22          1      Downtown_Bk
#  75        23          0      Downtown_Bk
#  76        24          1      Downtown_Bk
#  77        25          5      Downtown_Bk
#  78         0          7      Bayridge_bk
#  79         1         13      Bayridge_bk
#  80         2          5      Bayridge_bk
#  81         3          1      Bayridge_bk
#  82         4          1      Bayridge_bk
#  83         5          4      Bayridge_bk
#  84         6          0      Bayridge_bk
#  85         7          0      Bayridge_bk
#  86         8          2      Bayridge_bk
#  87         9          1      Bayridge_bk
#  88        10          1      Bayridge_bk
#  89        11          2      Bayridge_bk
#  90        12          0      Bayridge_bk
#  91        13          1      Bayridge_bk
#  92        14          0      Bayridge_bk
#  93        15          1      Bayridge_bk
#  94        16          0      Bayridge_bk
#  95        17          0      Bayridge_bk
#  96        18          0      Bayridge_bk
#  97        19          0      Bayridge_bk
#  98        20          0      Bayridge_bk
#  99        21          0      Bayridge_bk
#  100       22          0      Bayridge_bk
#  101       23          0      Bayridge_bk
#  102       24          0      Bayridge_bk
#  103       25          0      Bayridge_bk
#
#  [104 rows x 3 columns]]
