# %%
import pandas as pd
import geopandas as gp
from fiona.crs import from_epsg
import shapely
import matplotlib.pylab as plt
import csv
import dateutil
import os
from shapely.geometry import Point
# %matplotlib inline

# %%
# files for each year like:
## <neighborhood/borough of pick up>,<distance>,<ended on Manhattan (0/1)>,<number of trips>.

# %%
def clean_columns(data,year):
    
    data.columns = map(lambda x: x.strip(), list(data.columns))
    data.columns = map(lambda x: x.lower(), list(data.columns))
        
    if (year == '2014') | (year == '2013'):
        data.drop([u'vendor_id', u'passenger_count', u'rate_code', u'store_and_fwd_flag',
                   'dropoff_longitude','dropoff_latitude', u'payment_type',u'fare_amount', 
                   u'surcharge', u'mta_tax', u'tip_amount',
                   u'tolls_amount', u'total_amount'], axis = 1, inplace = True)
        
    elif year == '2015':
        data.drop([u'vendorid', u'passenger_count', u'ratecodeid', u'store_and_fwd_flag',
                   u'dropoff_longitude', u'dropoff_latitude', u'payment_type',
                   u'fare_amount', u'extra', u'mta_tax', u'tip_amount', u'tolls_amount',
                   u'improvement_surcharge', u'total_amount'], axis = 1, inplace = True)
    
    elif year == '2016':    
        data.drop([u'vendorid', u'passenger_count', u'ratecodeid', u'store_and_fwd_flag',
                   u'dropoff_longitude', u'dropoff_latitude', u'payment_type',
                   u'fare_amount', u'extra', u'mta_tax', u'tip_amount', u'tolls_amount',
                   u'improvement_surcharge', u'total_amount'], axis = 1, inplace = True)
    
    data.columns = ['date', 'dropoff_datetime', 'trip_distance', 
                    'pickup_longitude', 'pickup_latitude']
    
    return data

# %%
def segregate(data):
    
    man_upper = [24,151,238,75, 236, 263, 262, 239, 143, 142, 237, 141, 140]
    man_lower = [4, 79,113, 114, 249, 158, 125, 211, 144, 148, 232, 13, 231, 45,209,87,88,12,261]
    bk_dwn = [17,  25,  33, 49,  40,  34, 52, 54, 65, 106, 97, 66, 181, 189, 190, 195]
    bk_br = [11, 14, 22, 26, 67, 111, 227, 228]
    
    groups = range(0,25)
    groups.extend([25,data.trip_distance.max()])
    data['trip_cat'] = pd.cut(data.trip_distance, groups, labels=groups[:-1])
    data_man_upper = data[data.LocationID.isin(man_upper)]
    data_man_lower = data[data.LocationID.isin(man_lower)]
    data_bk_dwn = data[data.LocationID.isin(bk_dwn)]
    data_bk_br = data[data.LocationID.isin(bk_br)]
    
    data_man_upper = data_man_upper.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_man_lower = data_man_lower.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_bk_dwn = data_bk_dwn.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_bk_br = data_bk_br.groupby(['trip_cat']).agg({'LocationID':'count'})
        
    data_man_upper.reset_index(inplace=True)
    data_man_lower.reset_index(inplace=True)
    data_bk_dwn.reset_index(inplace=True)
    data_bk_br.reset_index(inplace=True)
    

    data_man_upper.loc[:, 'neighbourhood'] =  'upper_manhattan'
    data_man_lower.loc[:, 'neighbourhood'] =  'lower_manhattan'
    data_bk_dwn.loc[:, 'neighbourhood'] =  'Downtown_Bk'
    data_bk_br.loc[:, 'neighbourhood'] =  'Bayridge_bk'
    
    data = pd.concat([data_man_upper, data_man_lower, data_bk_dwn, data_bk_br], axis=0, ignore_index=True)
    data.columns = ['trip_cat', 'num_rides', 'neighbourhood']
    
    return data

# %%
def data_aggregator(data, tzone):
    
#     data["date"] = pd.to_datetime(data["date"])

    crs = {'init': 'epsg:4326', 'no_defs': True}
    geometry = [Point(xy) for xy in zip(data["pickup_longitude"], data["pickup_latitude"])]
    data = data.drop(["pickup_longitude", "pickup_latitude"], axis=1)
    data = gp.GeoDataFrame(data, crs=crs, geometry=geometry)

    print "Spatially joining data and taxi zones"
    data_geo = gp.sjoin(tzones, data) 
    data_geo = data_geo[['LocationID','trip_distance']]   
    
    print "Segregating"
    data_agg = segregate(data_geo)
    
    return data_agg

# %%
# Read data by month
def yellow_taxi(tzones): 
    
    
    if not (os.path.isdir("../../Data/Dist_agg")):
        print "Creating Folder Data/Dist_agg"
        os.system("mkdir ../../Data/Dist_agg")
        
#     year = ['2014', '2015']
#     months = ['01','02','03','04','05','06','07','08','09','10','11','12']
    year = ['2015']
#     months = ['10','11','12']
    months = ['12']

    yellow = []
    for y in year:
        for m in months:
            
            print "Reading Data/Yellow/yellow_tripdata_" + y + "-" + m + ".csv"
            data = pd.read_csv("../../Data/Yellow/yellow_tripdata_" + y + "-" + m + ".csv")
            print "Cleaning columns"
            data = clean_columns(data, y)
            print "Aggregating data"
            data_agg = data_aggregator(data, tzones)
            data_agg.to_csv("../../Data/Dist_agg/yellow_"+ y + "-" + m + ".csv")
            print 'Done'
            yellow.append(data_agg)
    
    return yellow

# %%
tzones = gp.read_file("../../Data/taxi_zones/taxi_zones_updated.shp")
tzones.to_crs(epsg=4326, inplace=True)

# %%
data = yellow_taxi(tzones)
# Out:
# Reading Data/Yellow/yellow_tripdata_2015-12.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done

# %%
def clean_columns_green(data,year, month):
    
    data.columns = map(lambda x: x.strip(), list(data.columns))
    data.columns = map(lambda x: x.lower(), list(data.columns))
    
    if (((year == '2015') & (month in ['07', '08', '09', '10', '11', '12'])) | (year == '2016')):
        data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                   u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                   u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                   u'improvement_surcharge', u'total_amount', u'payment_type',
                   u'trip_type'], axis = 1, inplace = True)
    
    else: 
    
        cols = data.columns
        data.reset_index(inplace=True)
        data = data.iloc[:,:len(cols)]
        data.columns = cols
        
        if year == '2015':
            data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                       u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                       u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                       u'improvement_surcharge', u'total_amount', u'payment_type',
                       u'trip_type'], axis = 1, inplace = True)
        
        elif (year == '2014') | (year == '2013'):
            data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                       u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                       u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                       u'total_amount', u'payment_type', u'trip_type'], axis = 1, inplace = True)
               
    data.columns = ['date', 'dropoff_datetime','pickup_longitude', 'pickup_latitude', 
                    'trip_distance']
    
    return data

# Read data by month
def green_taxi(tzones): 
    
    
    if not (os.path.isdir("../../Data/Dist_agg")):
        print "Creating Folder Data/Dist_agg"
        os.system("mkdir ../../Data/Dist_agg")
        
#     year = ['2014', '2015']
#     months = ['01','02','03','04','05','06','07','08','09','10','11','12']
    year = ['2014', '2015']
    months = ['10','11','12']

    green = []
    for y in year:
        for m in months:
            
            print "Reading Data/Green/green_tripdata_" + y + "-" + m + ".csv"
            data = pd.read_csv("../../Data/Green/green_tripdata_" + y + "-" + m + ".csv")
            print "Cleaning columns"
            data = clean_columns_green(data, y, m)
            print "Aggregating data"
            data_agg = data_aggregator(data, tzones)
            data_agg.to_csv("../../Data/Dist_agg/green_"+ y + "-" + m + ".csv")
            print 'Done'
            green.append(data_agg)
    
    return green

# %%
green_taxi(tzones)
# Out:
# Reading Data/Green/green_tripdata_2014-10.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2014-11.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2014-12.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-10.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-11.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-12.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# [    trip_cat  num_rides    neighbourhood
#  0          0      17610  upper_manhattan
#  1          1      28403  upper_manhattan
#  2          2      13147  upper_manhattan
#  3          3       6415  upper_manhattan
#  4          4       3755  upper_manhattan
#  5          5       2905  upper_manhattan
#  6          6       2062  upper_manhattan
#  7          7       1739  upper_manhattan
#  8          8       1017  upper_manhattan
#  9          9        580  upper_manhattan
#  10        10        318  upper_manhattan
#  11        11        233  upper_manhattan
#  12        12        126  upper_manhattan
#  13        13         93  upper_manhattan
#  14        14         85  upper_manhattan
#  15        15         66  upper_manhattan
#  16        16         73  upper_manhattan
#  17        17        182  upper_manhattan
#  18        18        350  upper_manhattan
#  19        19         53  upper_manhattan
#  20        20         29  upper_manhattan
#  21        21         14  upper_manhattan
#  22        22         11  upper_manhattan
#  23        23          3  upper_manhattan
#  24        24          2  upper_manhattan
#  25        25         58  upper_manhattan
#  26         0          2  lower_manhattan
#  27         1          5  lower_manhattan
#  28         2          7  lower_manhattan
#  29         3          5  lower_manhattan
#  ..       ...        ...              ...
#  74        22         58      Downtown_Bk
#  75        23         28      Downtown_Bk
#  76        24         31      Downtown_Bk
#  77        25        215      Downtown_Bk
#  78         0        794      Bayridge_bk
#  79         1       1289      Bayridge_bk
#  80         2        874      Bayridge_bk
#  81         3        563      Bayridge_bk
#  82         4        341      Bayridge_bk
#  83         5        266      Bayridge_bk
#  84         6        266      Bayridge_bk
#  85         7        262      Bayridge_bk
#  86         8        158      Bayridge_bk
#  87         9        117      Bayridge_bk
#  88        10        116      Bayridge_bk
#  89        11         61      Bayridge_bk
#  90        12         45      Bayridge_bk
#  91        13         55      Bayridge_bk
#  92        14         32      Bayridge_bk
#  93        15         13      Bayridge_bk
#  94        16         18      Bayridge_bk
#  95        17         16      Bayridge_bk
#  96        18         12      Bayridge_bk
#  97        19          7      Bayridge_bk
#  98        20          9      Bayridge_bk
#  99        21          7      Bayridge_bk
#  100       22          8      Bayridge_bk
#  101       23          7      Bayridge_bk
#  102       24         10      Bayridge_bk
#  103       25         13      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      17412  upper_manhattan
#  1          1      26786  upper_manhattan
#  2          2      12059  upper_manhattan
#  3          3       6117  upper_manhattan
#  4          4       3516  upper_manhattan
#  5          5       2691  upper_manhattan
#  6          6       2005  upper_manhattan
#  7          7       1561  upper_manhattan
#  8          8        922  upper_manhattan
#  9          9        531  upper_manhattan
#  10        10        320  upper_manhattan
#  11        11        241  upper_manhattan
#  12        12        136  upper_manhattan
#  13        13         97  upper_manhattan
#  14        14         85  upper_manhattan
#  15        15         71  upper_manhattan
#  16        16         42  upper_manhattan
#  17        17        136  upper_manhattan
#  18        18        279  upper_manhattan
#  19        19         78  upper_manhattan
#  20        20         17  upper_manhattan
#  21        21         12  upper_manhattan
#  22        22          7  upper_manhattan
#  23        23          6  upper_manhattan
#  24        24          6  upper_manhattan
#  25        25         47  upper_manhattan
#  26         0          2  lower_manhattan
#  27         1          3  lower_manhattan
#  28         2          1  lower_manhattan
#  29         3          1  lower_manhattan
#  ..       ...        ...              ...
#  74        22         42      Downtown_Bk
#  75        23         33      Downtown_Bk
#  76        24         39      Downtown_Bk
#  77        25        179      Downtown_Bk
#  78         0        905      Bayridge_bk
#  79         1       1417      Bayridge_bk
#  80         2        950      Bayridge_bk
#  81         3        623      Bayridge_bk
#  82         4        338      Bayridge_bk
#  83         5        281      Bayridge_bk
#  84         6        271      Bayridge_bk
#  85         7        285      Bayridge_bk
#  86         8        203      Bayridge_bk
#  87         9        176      Bayridge_bk
#  88        10        163      Bayridge_bk
#  89        11        102      Bayridge_bk
#  90        12         92      Bayridge_bk
#  91        13         76      Bayridge_bk
#  92        14         49      Bayridge_bk
#  93        15         31      Bayridge_bk
#  94        16         26      Bayridge_bk
#  95        17         16      Bayridge_bk
#  96        18         11      Bayridge_bk
#  97        19          9      Bayridge_bk
#  98        20         14      Bayridge_bk
#  99        21          4      Bayridge_bk
#  100       22         14      Bayridge_bk
#  101       23         11      Bayridge_bk
#  102       24          8      Bayridge_bk
#  103       25         12      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      19736  upper_manhattan
#  1          1      28899  upper_manhattan
#  2          2      12743  upper_manhattan
#  3          3       6208  upper_manhattan
#  4          4       3433  upper_manhattan
#  5          5       2714  upper_manhattan
#  6          6       1933  upper_manhattan
#  7          7       1624  upper_manhattan
#  8          8       1006  upper_manhattan
#  9          9        551  upper_manhattan
#  10        10        319  upper_manhattan
#  11        11        221  upper_manhattan
#  12        12        162  upper_manhattan
#  13        13        103  upper_manhattan
#  14        14         80  upper_manhattan
#  15        15         78  upper_manhattan
#  16        16         57  upper_manhattan
#  17        17        178  upper_manhattan
#  18        18        338  upper_manhattan
#  19        19         55  upper_manhattan
#  20        20         20  upper_manhattan
#  21        21         21  upper_manhattan
#  22        22         12  upper_manhattan
#  23        23          6  upper_manhattan
#  24        24         11  upper_manhattan
#  25        25         51  upper_manhattan
#  26         0          2  lower_manhattan
#  27         1          1  lower_manhattan
#  28         2          2  lower_manhattan
#  29         3          7  lower_manhattan
#  ..       ...        ...              ...
#  74        22         50      Downtown_Bk
#  75        23         39      Downtown_Bk
#  76        24         50      Downtown_Bk
#  77        25        234      Downtown_Bk
#  78         0       1018      Bayridge_bk
#  79         1       1618      Bayridge_bk
#  80         2       1080      Bayridge_bk
#  81         3        675      Bayridge_bk
#  82         4        467      Bayridge_bk
#  83         5        369      Bayridge_bk
#  84         6        267      Bayridge_bk
#  85         7        256      Bayridge_bk
#  86         8        188      Bayridge_bk
#  87         9        142      Bayridge_bk
#  88        10        112      Bayridge_bk
#  89        11         92      Bayridge_bk
#  90        12         78      Bayridge_bk
#  91        13         74      Bayridge_bk
#  92        14         40      Bayridge_bk
#  93        15         43      Bayridge_bk
#  94        16         18      Bayridge_bk
#  95        17         12      Bayridge_bk
#  96        18         12      Bayridge_bk
#  97        19         20      Bayridge_bk
#  98        20         14      Bayridge_bk
#  99        21         12      Bayridge_bk
#  100       22          5      Bayridge_bk
#  101       23          8      Bayridge_bk
#  102       24          6      Bayridge_bk
#  103       25         10      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      19900  upper_manhattan
#  1          1      30621  upper_manhattan
#  2          2      13317  upper_manhattan
#  3          3       6311  upper_manhattan
#  4          4       3658  upper_manhattan
#  5          5       2787  upper_manhattan
#  6          6       2025  upper_manhattan
#  7          7       1599  upper_manhattan
#  8          8       1008  upper_manhattan
#  9          9        550  upper_manhattan
#  10        10        362  upper_manhattan
#  11        11        272  upper_manhattan
#  12        12        132  upper_manhattan
#  13        13        116  upper_manhattan
#  14        14         76  upper_manhattan
#  15        15        100  upper_manhattan
#  16        16         76  upper_manhattan
#  17        17        173  upper_manhattan
#  18        18        335  upper_manhattan
#  19        19         65  upper_manhattan
#  20        20         26  upper_manhattan
#  21        21         23  upper_manhattan
#  22        22         18  upper_manhattan
#  23        23          8  upper_manhattan
#  24        24          3  upper_manhattan
#  25        25         68  upper_manhattan
#  26         0          2  lower_manhattan
#  27         1          1  lower_manhattan
#  28         2          2  lower_manhattan
#  29         3          0  lower_manhattan
#  ..       ...        ...              ...
#  74        22         54      Downtown_Bk
#  75        23         52      Downtown_Bk
#  76        24         55      Downtown_Bk
#  77        25        312      Downtown_Bk
#  78         0       1225      Bayridge_bk
#  79         1       1784      Bayridge_bk
#  80         2       1229      Bayridge_bk
#  81         3        801      Bayridge_bk
#  82         4        483      Bayridge_bk
#  83         5        371      Bayridge_bk
#  84         6        337      Bayridge_bk
#  85         7        289      Bayridge_bk
#  86         8        206      Bayridge_bk
#  87         9        158      Bayridge_bk
#  88        10        109      Bayridge_bk
#  89        11         91      Bayridge_bk
#  90        12        100      Bayridge_bk
#  91        13         59      Bayridge_bk
#  92        14         38      Bayridge_bk
#  93        15         41      Bayridge_bk
#  94        16         21      Bayridge_bk
#  95        17         23      Bayridge_bk
#  96        18         11      Bayridge_bk
#  97        19         18      Bayridge_bk
#  98        20         10      Bayridge_bk
#  99        21         10      Bayridge_bk
#  100       22          8      Bayridge_bk
#  101       23          8      Bayridge_bk
#  102       24          5      Bayridge_bk
#  103       25         15      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      18401  upper_manhattan
#  1          1      27848  upper_manhattan
#  2          2      12129  upper_manhattan
#  3          3       5674  upper_manhattan
#  4          4       3103  upper_manhattan
#  5          5       2571  upper_manhattan
#  6          6       1865  upper_manhattan
#  7          7       1521  upper_manhattan
#  8          8        950  upper_manhattan
#  9          9        523  upper_manhattan
#  10        10        348  upper_manhattan
#  11        11        222  upper_manhattan
#  12        12        114  upper_manhattan
#  13        13         95  upper_manhattan
#  14        14         94  upper_manhattan
#  15        15         93  upper_manhattan
#  16        16         60  upper_manhattan
#  17        17        169  upper_manhattan
#  18        18        267  upper_manhattan
#  19        19         56  upper_manhattan
#  20        20         25  upper_manhattan
#  21        21         19  upper_manhattan
#  22        22          9  upper_manhattan
#  23        23          8  upper_manhattan
#  24        24          5  upper_manhattan
#  25        25         55  upper_manhattan
#  26         0          2  lower_manhattan
#  27         1          0  lower_manhattan
#  28         2          3  lower_manhattan
#  29         3          1  lower_manhattan
#  ..       ...        ...              ...
#  74        22         52      Downtown_Bk
#  75        23         40      Downtown_Bk
#  76        24         33      Downtown_Bk
#  77        25        255      Downtown_Bk
#  78         0       1149      Bayridge_bk
#  79         1       1707      Bayridge_bk
#  80         2       1178      Bayridge_bk
#  81         3        761      Bayridge_bk
#  82         4        461      Bayridge_bk
#  83         5        381      Bayridge_bk
#  84         6        353      Bayridge_bk
#  85         7        332      Bayridge_bk
#  86         8        255      Bayridge_bk
#  87         9        202      Bayridge_bk
#  88        10        149      Bayridge_bk
#  89        11         99      Bayridge_bk
#  90        12         94      Bayridge_bk
#  91        13        106      Bayridge_bk
#  92        14         62      Bayridge_bk
#  93        15         51      Bayridge_bk
#  94        16         24      Bayridge_bk
#  95        17         14      Bayridge_bk
#  96        18         15      Bayridge_bk
#  97        19         22      Bayridge_bk
#  98        20          8      Bayridge_bk
#  99        21          8      Bayridge_bk
#  100       22         16      Bayridge_bk
#  101       23         14      Bayridge_bk
#  102       24          6      Bayridge_bk
#  103       25         14      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      20111  upper_manhattan
#  1          1      29558  upper_manhattan
#  2          2      12756  upper_manhattan
#  3          3       5881  upper_manhattan
#  4          4       3259  upper_manhattan
#  5          5       2604  upper_manhattan
#  6          6       1919  upper_manhattan
#  7          7       1573  upper_manhattan
#  8          8        968  upper_manhattan
#  9          9        524  upper_manhattan
#  10        10        354  upper_manhattan
#  11        11        233  upper_manhattan
#  12        12        144  upper_manhattan
#  13        13        117  upper_manhattan
#  14        14         78  upper_manhattan
#  15        15         94  upper_manhattan
#  16        16         56  upper_manhattan
#  17        17        197  upper_manhattan
#  18        18        308  upper_manhattan
#  19        19         65  upper_manhattan
#  20        20         24  upper_manhattan
#  21        21         13  upper_manhattan
#  22        22         12  upper_manhattan
#  23        23          6  upper_manhattan
#  24        24          7  upper_manhattan
#  25        25         53  upper_manhattan
#  26         0          0  lower_manhattan
#  27         1          0  lower_manhattan
#  28         2          0  lower_manhattan
#  29         3          1  lower_manhattan
#  ..       ...        ...              ...
#  74        22         48      Downtown_Bk
#  75        23         41      Downtown_Bk
#  76        24         51      Downtown_Bk
#  77        25        270      Downtown_Bk
#  78         0       1193      Bayridge_bk
#  79         1       1793      Bayridge_bk
#  80         2       1251      Bayridge_bk
#  81         3        783      Bayridge_bk
#  82         4        443      Bayridge_bk
#  83         5        380      Bayridge_bk
#  84         6        326      Bayridge_bk
#  85         7        265      Bayridge_bk
#  86         8        182      Bayridge_bk
#  87         9        160      Bayridge_bk
#  88        10        117      Bayridge_bk
#  89        11         93      Bayridge_bk
#  90        12         70      Bayridge_bk
#  91        13         83      Bayridge_bk
#  92        14         63      Bayridge_bk
#  93        15         38      Bayridge_bk
#  94        16         33      Bayridge_bk
#  95        17         23      Bayridge_bk
#  96        18         23      Bayridge_bk
#  97        19         16      Bayridge_bk
#  98        20         17      Bayridge_bk
#  99        21          9      Bayridge_bk
#  100       22         12      Bayridge_bk
#  101       23         11      Bayridge_bk
#  102       24         10      Bayridge_bk
#  103       25         18      Bayridge_bk
#
#  [104 rows x 3 columns]]
