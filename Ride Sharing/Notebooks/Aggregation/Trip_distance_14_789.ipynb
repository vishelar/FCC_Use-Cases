# %%
import pandas as pd
import geopandas as gp
from fiona.crs import from_epsg
import shapely
import matplotlib.pylab as plt
import csv
import dateutil
import os
from shapely.geometry import Point
# %matplotlib inline

# %%
# files for each year like:
## <neighborhood/borough of pick up>,<distance>,<ended on Manhattan (0/1)>,<number of trips>.

# %%
def clean_columns(data,year):
    
    data.columns = map(lambda x: x.strip(), list(data.columns))
    data.columns = map(lambda x: x.lower(), list(data.columns))
        
    if (year == '2014') | (year == '2013'):
        data.drop([u'vendor_id', u'passenger_count', u'rate_code', u'store_and_fwd_flag',
                   'dropoff_longitude','dropoff_latitude', u'payment_type',u'fare_amount', 
                   u'surcharge', u'mta_tax', u'tip_amount',
                   u'tolls_amount', u'total_amount'], axis = 1, inplace = True)
        
    elif year == '2015':
        data.drop([u'vendorid', u'passenger_count', u'ratecodeid', u'store_and_fwd_flag',
                   u'dropoff_longitude', u'dropoff_latitude', u'payment_type',
                   u'fare_amount', u'extra', u'mta_tax', u'tip_amount', u'tolls_amount',
                   u'improvement_surcharge', u'total_amount'], axis = 1, inplace = True)
    
    elif year == '2016':    
        data.drop([u'vendorid', u'passenger_count', u'ratecodeid', u'store_and_fwd_flag',
                   u'dropoff_longitude', u'dropoff_latitude', u'payment_type',
                   u'fare_amount', u'extra', u'mta_tax', u'tip_amount', u'tolls_amount',
                   u'improvement_surcharge', u'total_amount'], axis = 1, inplace = True)
    
    data.columns = ['date', 'dropoff_datetime', 'trip_distance', 
                    'pickup_longitude', 'pickup_latitude']
    
    return data

# %%
def segregate(data):
    
    man_upper = [24,151,238,75, 236, 263, 262, 239, 143, 142, 237, 141, 140]
    man_lower = [4, 79,113, 114, 249, 158, 125, 211, 144, 148, 232, 13, 231, 45,209,87,88,12,261]
    bk_dwn = [17,  25,  33, 49,  40,  34, 52, 54, 65, 106, 97, 66, 181, 189, 190, 195]
    bk_br = [11, 14, 22, 26, 67, 111, 227, 228]
    
    groups = range(0,25)
    groups.extend([25,data.trip_distance.max()])
    data['trip_cat'] = pd.cut(data.trip_distance, groups, labels=groups[:-1])
    data_man_upper = data[data.LocationID.isin(man_upper)]
    data_man_lower = data[data.LocationID.isin(man_lower)]
    data_bk_dwn = data[data.LocationID.isin(bk_dwn)]
    data_bk_br = data[data.LocationID.isin(bk_br)]
    
    data_man_upper = data_man_upper.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_man_lower = data_man_lower.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_bk_dwn = data_bk_dwn.groupby(['trip_cat']).agg({'LocationID':'count'})
    data_bk_br = data_bk_br.groupby(['trip_cat']).agg({'LocationID':'count'})
        
    data_man_upper.reset_index(inplace=True)
    data_man_lower.reset_index(inplace=True)
    data_bk_dwn.reset_index(inplace=True)
    data_bk_br.reset_index(inplace=True)
    

    data_man_upper.loc[:, 'neighbourhood'] =  'upper_manhattan'
    data_man_lower.loc[:, 'neighbourhood'] =  'lower_manhattan'
    data_bk_dwn.loc[:, 'neighbourhood'] =  'Downtown_Bk'
    data_bk_br.loc[:, 'neighbourhood'] =  'Bayridge_bk'
    
    data = pd.concat([data_man_upper, data_man_lower, data_bk_dwn, data_bk_br], axis=0, ignore_index=True)
    data.columns = ['trip_cat', 'num_rides', 'neighbourhood']
    
    return data

# %%
def data_aggregator(data, tzone):
    
#     data["date"] = pd.to_datetime(data["date"])

    crs = {'init': 'epsg:4326', 'no_defs': True}
    geometry = [Point(xy) for xy in zip(data["pickup_longitude"], data["pickup_latitude"])]
    data = data.drop(["pickup_longitude", "pickup_latitude"], axis=1)
    data = gp.GeoDataFrame(data, crs=crs, geometry=geometry)

    print "Spatially joining data and taxi zones"
    data_geo = gp.sjoin(tzones, data) 
    data_geo = data_geo[['LocationID','trip_distance']]   
    
    print "Segregating"
    data_agg = segregate(data_geo)
    
    return data_agg

# %%
# Read data by month
def yellow_taxi(tzones): 
    
    
    if not (os.path.isdir("../../Data/Dist_agg")):
        print "Creating Folder Data/Dist_agg"
        os.system("mkdir ../../Data/Dist_agg")
        
#     year = ['2014', '2015']
#     months = ['01','02','03','04','05','06','07','08','09','10','11','12']
    year = ['2015']
    months = ['07','08','09']

    yellow = []
    for y in year:
        for m in months:
            
            print "Reading Data/Yellow/yellow_tripdata_" + y + "-" + m + ".csv"
            data = pd.read_csv("../../Data/Yellow/yellow_tripdata_" + y + "-" + m + ".csv")
            print "Cleaning columns"
            data = clean_columns(data, y)
            print "Aggregating data"
            data_agg = data_aggregator(data, tzones)
            data_agg.to_csv("../../Data/Dist_agg/yellow_"+ y + "-" + m + ".csv")
            print 'Done'
            yellow.append(data_agg)
    
    return yellow

# %%
tzones = gp.read_file("../../Data/taxi_zones/taxi_zones_updated.shp")
tzones.to_crs(epsg=4326, inplace=True)

# %%
data = yellow_taxi(tzones)
# Out:
# Reading Data/Yellow/yellow_tripdata_2015-07.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Yellow/yellow_tripdata_2015-08.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Yellow/yellow_tripdata_2015-09.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done

# %%
def clean_columns_green(data,year, month):
    
    data.columns = map(lambda x: x.strip(), list(data.columns))
    data.columns = map(lambda x: x.lower(), list(data.columns))
    
    if (((year == '2015') & (month in ['07', '08', '09', '10', '11', '12'])) | (year == '2016')):
        data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                   u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                   u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                   u'improvement_surcharge', u'total_amount', u'payment_type',
                   u'trip_type'], axis = 1, inplace = True)
    
    else: 
    
        cols = data.columns
        data.reset_index(inplace=True)
        data = data.iloc[:,:len(cols)]
        data.columns = cols
        
        if year == '2015':
            data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                       u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                       u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                       u'improvement_surcharge', u'total_amount', u'payment_type',
                       u'trip_type'], axis = 1, inplace = True)
        
        elif (year == '2014') | (year == '2013'):
            data.drop([u'vendorid',u'store_and_fwd_flag', u'ratecodeid', u'dropoff_longitude', 
                       u'dropoff_latitude', u'passenger_count', u'fare_amount', u'extra',
                       u'mta_tax', u'tip_amount', u'tolls_amount', u'ehail_fee',
                       u'total_amount', u'payment_type', u'trip_type'], axis = 1, inplace = True)
               
    data.columns = ['date', 'dropoff_datetime','pickup_longitude', 'pickup_latitude', 
                    'trip_distance']
    
    return data

# Read data by month
def green_taxi(tzones): 
    
    
    if not (os.path.isdir("../../Data/Dist_agg")):
        print "Creating Folder Data/Dist_agg"
        os.system("mkdir ../../Data/Dist_agg")
        
#     year = ['2014', '2015']
#     months = ['01','02','03','04','05','06','07','08','09','10','11','12']
    year = ['2014', '2015']
    months = ['07','08','09']

    green = []
    for y in year:
        for m in months:
            
            print "Reading Data/Green/green_tripdata_" + y + "-" + m + ".csv"
            data = pd.read_csv("../../Data/Green/green_tripdata_" + y + "-" + m + ".csv")
            print "Cleaning columns"
            data = clean_columns_green(data, y, m)
            print "Aggregating data"
            data_agg = data_aggregator(data, tzones)
            data_agg.to_csv("../../Data/Dist_agg/green_"+ y + "-" + m + ".csv")
            print 'Done'
            green.append(data_agg)
    
    return green

# %%
green_taxi(tzones)
# Out:
# Reading Data/Green/green_tripdata_2014-07.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2014-08.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2014-09.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-07.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-08.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# Reading Data/Green/green_tripdata_2015-09.csv
# Cleaning columns
# Aggregating data
# Spatially joining data and taxi zones
# Segregating
# Done
# [    trip_cat  num_rides    neighbourhood
#  0          0      13291  upper_manhattan
#  1          1      21793  upper_manhattan
#  2          2      10414  upper_manhattan
#  3          3       5554  upper_manhattan
#  4          4       3237  upper_manhattan
#  5          5       2360  upper_manhattan
#  6          6       1661  upper_manhattan
#  7          7       1443  upper_manhattan
#  8          8        920  upper_manhattan
#  9          9        557  upper_manhattan
#  10        10        295  upper_manhattan
#  11        11        175  upper_manhattan
#  12        12        122  upper_manhattan
#  13        13         87  upper_manhattan
#  14        14         80  upper_manhattan
#  15        15         56  upper_manhattan
#  16        16         55  upper_manhattan
#  17        17        139  upper_manhattan
#  18        18        281  upper_manhattan
#  19        19         47  upper_manhattan
#  20        20         26  upper_manhattan
#  21        21         16  upper_manhattan
#  22        22          4  upper_manhattan
#  23        23          9  upper_manhattan
#  24        24          3  upper_manhattan
#  25        25         34  upper_manhattan
#  26         0          2  lower_manhattan
#  27         1          5  lower_manhattan
#  28         2         27  lower_manhattan
#  29         3         34  lower_manhattan
#  ..       ...        ...              ...
#  74        22         34      Downtown_Bk
#  75        23         24      Downtown_Bk
#  76        24         21      Downtown_Bk
#  77        25        166      Downtown_Bk
#  78         0        492      Bayridge_bk
#  79         1        906      Bayridge_bk
#  80         2        785      Bayridge_bk
#  81         3        467      Bayridge_bk
#  82         4        304      Bayridge_bk
#  83         5        244      Bayridge_bk
#  84         6        205      Bayridge_bk
#  85         7        212      Bayridge_bk
#  86         8        168      Bayridge_bk
#  87         9        104      Bayridge_bk
#  88        10         80      Bayridge_bk
#  89        11         62      Bayridge_bk
#  90        12         44      Bayridge_bk
#  91        13         42      Bayridge_bk
#  92        14         31      Bayridge_bk
#  93        15         24      Bayridge_bk
#  94        16         12      Bayridge_bk
#  95        17          8      Bayridge_bk
#  96        18          3      Bayridge_bk
#  97        19          5      Bayridge_bk
#  98        20          7      Bayridge_bk
#  99        21          5      Bayridge_bk
#  100       22          5      Bayridge_bk
#  101       23          8      Bayridge_bk
#  102       24          5      Bayridge_bk
#  103       25         10      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      12973  upper_manhattan
#  1          1      21021  upper_manhattan
#  2          2      10006  upper_manhattan
#  3          3       5584  upper_manhattan
#  4          4       3264  upper_manhattan
#  5          5       2357  upper_manhattan
#  6          6       1759  upper_manhattan
#  7          7       1474  upper_manhattan
#  8          8        885  upper_manhattan
#  9          9        513  upper_manhattan
#  10        10        287  upper_manhattan
#  11        11        160  upper_manhattan
#  12        12        132  upper_manhattan
#  13        13         90  upper_manhattan
#  14        14         83  upper_manhattan
#  15        15         69  upper_manhattan
#  16        16         57  upper_manhattan
#  17        17        165  upper_manhattan
#  18        18        275  upper_manhattan
#  19        19         55  upper_manhattan
#  20        20         30  upper_manhattan
#  21        21         11  upper_manhattan
#  22        22          9  upper_manhattan
#  23        23         11  upper_manhattan
#  24        24          4  upper_manhattan
#  25        25         31  upper_manhattan
#  26         0          1  lower_manhattan
#  27         1          4  lower_manhattan
#  28         2         14  lower_manhattan
#  29         3         25  lower_manhattan
#  ..       ...        ...              ...
#  74        22         39      Downtown_Bk
#  75        23         35      Downtown_Bk
#  76        24         21      Downtown_Bk
#  77        25        132      Downtown_Bk
#  78         0        493      Bayridge_bk
#  79         1        914      Bayridge_bk
#  80         2        718      Bayridge_bk
#  81         3        491      Bayridge_bk
#  82         4        316      Bayridge_bk
#  83         5        272      Bayridge_bk
#  84         6        224      Bayridge_bk
#  85         7        251      Bayridge_bk
#  86         8        107      Bayridge_bk
#  87         9        111      Bayridge_bk
#  88        10         79      Bayridge_bk
#  89        11         71      Bayridge_bk
#  90        12         55      Bayridge_bk
#  91        13         47      Bayridge_bk
#  92        14         31      Bayridge_bk
#  93        15         18      Bayridge_bk
#  94        16         19      Bayridge_bk
#  95        17         13      Bayridge_bk
#  96        18          8      Bayridge_bk
#  97        19         11      Bayridge_bk
#  98        20          6      Bayridge_bk
#  99        21          2      Bayridge_bk
#  100       22          6      Bayridge_bk
#  101       23          5      Bayridge_bk
#  102       24          8      Bayridge_bk
#  103       25          7      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      15273  upper_manhattan
#  1          1      24209  upper_manhattan
#  2          2      11010  upper_manhattan
#  3          3       5540  upper_manhattan
#  4          4       3245  upper_manhattan
#  5          5       2448  upper_manhattan
#  6          6       1806  upper_manhattan
#  7          7       1450  upper_manhattan
#  8          8        918  upper_manhattan
#  9          9        534  upper_manhattan
#  10        10        290  upper_manhattan
#  11        11        192  upper_manhattan
#  12        12        134  upper_manhattan
#  13        13         81  upper_manhattan
#  14        14         65  upper_manhattan
#  15        15         81  upper_manhattan
#  16        16         49  upper_manhattan
#  17        17        156  upper_manhattan
#  18        18        237  upper_manhattan
#  19        19         50  upper_manhattan
#  20        20         23  upper_manhattan
#  21        21         16  upper_manhattan
#  22        22         10  upper_manhattan
#  23        23          8  upper_manhattan
#  24        24          3  upper_manhattan
#  25        25         37  upper_manhattan
#  26         0          3  lower_manhattan
#  27         1          0  lower_manhattan
#  28         2          7  lower_manhattan
#  29         3          9  lower_manhattan
#  ..       ...        ...              ...
#  74        22         48      Downtown_Bk
#  75        23         23      Downtown_Bk
#  76        24         34      Downtown_Bk
#  77        25        175      Downtown_Bk
#  78         0        570      Bayridge_bk
#  79         1       1040      Bayridge_bk
#  80         2        695      Bayridge_bk
#  81         3        494      Bayridge_bk
#  82         4        302      Bayridge_bk
#  83         5        220      Bayridge_bk
#  84         6        215      Bayridge_bk
#  85         7        230      Bayridge_bk
#  86         8        137      Bayridge_bk
#  87         9        108      Bayridge_bk
#  88        10         91      Bayridge_bk
#  89        11         66      Bayridge_bk
#  90        12         55      Bayridge_bk
#  91        13         56      Bayridge_bk
#  92        14         24      Bayridge_bk
#  93        15         30      Bayridge_bk
#  94        16         17      Bayridge_bk
#  95        17         15      Bayridge_bk
#  96        18         12      Bayridge_bk
#  97        19          7      Bayridge_bk
#  98        20          8      Bayridge_bk
#  99        21          3      Bayridge_bk
#  100       22          5      Bayridge_bk
#  101       23          2      Bayridge_bk
#  102       24          5      Bayridge_bk
#  103       25         10      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      17522  upper_manhattan
#  1          1      25968  upper_manhattan
#  2          2      12012  upper_manhattan
#  3          3       6398  upper_manhattan
#  4          4       3731  upper_manhattan
#  5          5       2841  upper_manhattan
#  6          6       1840  upper_manhattan
#  7          7       1553  upper_manhattan
#  8          8        908  upper_manhattan
#  9          9        598  upper_manhattan
#  10        10        343  upper_manhattan
#  11        11        215  upper_manhattan
#  12        12        134  upper_manhattan
#  13        13        115  upper_manhattan
#  14        14         74  upper_manhattan
#  15        15         95  upper_manhattan
#  16        16         61  upper_manhattan
#  17        17        170  upper_manhattan
#  18        18        315  upper_manhattan
#  19        19         59  upper_manhattan
#  20        20         27  upper_manhattan
#  21        21         15  upper_manhattan
#  22        22         12  upper_manhattan
#  23        23          6  upper_manhattan
#  24        24          9  upper_manhattan
#  25        25         39  upper_manhattan
#  26         0          0  lower_manhattan
#  27         1          0  lower_manhattan
#  28         2          1  lower_manhattan
#  29         3          1  lower_manhattan
#  ..       ...        ...              ...
#  74        22         37      Downtown_Bk
#  75        23         25      Downtown_Bk
#  76        24         41      Downtown_Bk
#  77        25        241      Downtown_Bk
#  78         0       1229      Bayridge_bk
#  79         1       1865      Bayridge_bk
#  80         2       1278      Bayridge_bk
#  81         3        773      Bayridge_bk
#  82         4        498      Bayridge_bk
#  83         5        377      Bayridge_bk
#  84         6        310      Bayridge_bk
#  85         7        263      Bayridge_bk
#  86         8        179      Bayridge_bk
#  87         9        143      Bayridge_bk
#  88        10        114      Bayridge_bk
#  89        11         64      Bayridge_bk
#  90        12         74      Bayridge_bk
#  91        13         75      Bayridge_bk
#  92        14         50      Bayridge_bk
#  93        15         22      Bayridge_bk
#  94        16         24      Bayridge_bk
#  95        17         27      Bayridge_bk
#  96        18         15      Bayridge_bk
#  97        19         20      Bayridge_bk
#  98        20         13      Bayridge_bk
#  99        21         10      Bayridge_bk
#  100       22         11      Bayridge_bk
#  101       23          8      Bayridge_bk
#  102       24          8      Bayridge_bk
#  103       25         21      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      16264  upper_manhattan
#  1          1      23950  upper_manhattan
#  2          2      11147  upper_manhattan
#  3          3       6018  upper_manhattan
#  4          4       3520  upper_manhattan
#  5          5       2684  upper_manhattan
#  6          6       1892  upper_manhattan
#  7          7       1521  upper_manhattan
#  8          8        956  upper_manhattan
#  9          9        524  upper_manhattan
#  10        10        345  upper_manhattan
#  11        11        232  upper_manhattan
#  12        12        125  upper_manhattan
#  13        13        103  upper_manhattan
#  14        14         79  upper_manhattan
#  15        15         70  upper_manhattan
#  16        16         70  upper_manhattan
#  17        17        154  upper_manhattan
#  18        18        275  upper_manhattan
#  19        19         56  upper_manhattan
#  20        20         19  upper_manhattan
#  21        21         13  upper_manhattan
#  22        22         17  upper_manhattan
#  23        23         12  upper_manhattan
#  24        24          2  upper_manhattan
#  25        25         33  upper_manhattan
#  26         0          1  lower_manhattan
#  27         1          0  lower_manhattan
#  28         2          4  lower_manhattan
#  29         3          2  lower_manhattan
#  ..       ...        ...              ...
#  74        22         53      Downtown_Bk
#  75        23         38      Downtown_Bk
#  76        24         35      Downtown_Bk
#  77        25        219      Downtown_Bk
#  78         0       1200      Bayridge_bk
#  79         1       1841      Bayridge_bk
#  80         2       1209      Bayridge_bk
#  81         3        765      Bayridge_bk
#  82         4        507      Bayridge_bk
#  83         5        386      Bayridge_bk
#  84         6        347      Bayridge_bk
#  85         7        299      Bayridge_bk
#  86         8        198      Bayridge_bk
#  87         9        149      Bayridge_bk
#  88        10        124      Bayridge_bk
#  89        11         79      Bayridge_bk
#  90        12         90      Bayridge_bk
#  91        13         66      Bayridge_bk
#  92        14         43      Bayridge_bk
#  93        15         34      Bayridge_bk
#  94        16         24      Bayridge_bk
#  95        17         21      Bayridge_bk
#  96        18         11      Bayridge_bk
#  97        19         17      Bayridge_bk
#  98        20         18      Bayridge_bk
#  99        21         13      Bayridge_bk
#  100       22         14      Bayridge_bk
#  101       23         11      Bayridge_bk
#  102       24          5      Bayridge_bk
#  103       25         15      Bayridge_bk
#
#  [104 rows x 3 columns],     trip_cat  num_rides    neighbourhood
#  0          0      17676  upper_manhattan
#  1          1      27019  upper_manhattan
#  2          2      11895  upper_manhattan
#  3          3       5984  upper_manhattan
#  4          4       3360  upper_manhattan
#  5          5       2669  upper_manhattan
#  6          6       1895  upper_manhattan
#  7          7       1569  upper_manhattan
#  8          8       1006  upper_manhattan
#  9          9        593  upper_manhattan
#  10        10        343  upper_manhattan
#  11        11        245  upper_manhattan
#  12        12        134  upper_manhattan
#  13        13         97  upper_manhattan
#  14        14         68  upper_manhattan
#  15        15         89  upper_manhattan
#  16        16         55  upper_manhattan
#  17        17        164  upper_manhattan
#  18        18        259  upper_manhattan
#  19        19         57  upper_manhattan
#  20        20         33  upper_manhattan
#  21        21         17  upper_manhattan
#  22        22         15  upper_manhattan
#  23        23          5  upper_manhattan
#  24        24          7  upper_manhattan
#  25        25         63  upper_manhattan
#  26         0          1  lower_manhattan
#  27         1          0  lower_manhattan
#  28         2          2  lower_manhattan
#  29         3          4  lower_manhattan
#  ..       ...        ...              ...
#  74        22         53      Downtown_Bk
#  75        23         47      Downtown_Bk
#  76        24         38      Downtown_Bk
#  77        25        223      Downtown_Bk
#  78         0       1148      Bayridge_bk
#  79         1       1681      Bayridge_bk
#  80         2       1175      Bayridge_bk
#  81         3        798      Bayridge_bk
#  82         4        434      Bayridge_bk
#  83         5        337      Bayridge_bk
#  84         6        293      Bayridge_bk
#  85         7        286      Bayridge_bk
#  86         8        161      Bayridge_bk
#  87         9        140      Bayridge_bk
#  88        10         99      Bayridge_bk
#  89        11         78      Bayridge_bk
#  90        12         67      Bayridge_bk
#  91        13         65      Bayridge_bk
#  92        14         53      Bayridge_bk
#  93        15         25      Bayridge_bk
#  94        16         26      Bayridge_bk
#  95        17         20      Bayridge_bk
#  96        18         18      Bayridge_bk
#  97        19         14      Bayridge_bk
#  98        20         13      Bayridge_bk
#  99        21          4      Bayridge_bk
#  100       22         14      Bayridge_bk
#  101       23          7      Bayridge_bk
#  102       24         10      Bayridge_bk
#  103       25         16      Bayridge_bk
#
#  [104 rows x 3 columns]]
