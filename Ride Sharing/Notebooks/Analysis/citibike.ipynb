# %%
import pandas as pd
import os
import json
from shapely.geometry import Point
import geopandas as gp
import numpy as np
import urllib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Citibike Stations

# %%
url = "https://feeds.citibikenyc.com/stations/stations.json"
response = urllib.urlopen(url)
stations = json.loads(response.read())
    
# https://feeds.citibikenyc.com/stations/stations.json

# %%
stations
# Out:
# {u'executionTime': u'2017-04-23 07:33:57 PM',
#  u'stationBeanList': [{u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 30,
#    u'city': u'',
#    u'id': 72,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:26 PM',
#    u'latitude': 40.76727216,
#    u'location': u'',
#    u'longitude': -73.99392888,
#    u'postalCode': u'',
#    u'stAddress1': u'W 52 St & 11 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 52 St & 11 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 79,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:44 PM',
#    u'latitude': 40.71911552,
#    u'location': u'',
#    u'longitude': -74.00666661,
#    u'postalCode': u'',
#    u'stAddress1': u'Franklin St & W Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Franklin St & W Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 82,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-13 12:05:52 PM',
#    u'latitude': 40.71117416,
#    u'location': u'',
#    u'longitude': -74.00016545,
#    u'postalCode': u'',
#    u'stAddress1': u'St James Pl & Pearl St',
#    u'stAddress2': u'',
#    u'stationName': u'St James Pl & Pearl St',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 0},
#   {u'altitude': u'',
#    u'availableBikes': 18,
#    u'availableDocks': 41,
#    u'city': u'',
#    u'id': 83,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:40 PM',
#    u'latitude': 40.68382604,
#    u'location': u'',
#    u'longitude': -73.97632328,
#    u'postalCode': u'',
#    u'stAddress1': u'Atlantic Ave & Fort Greene Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Atlantic Ave & Fort Greene Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 62},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 23,
#    u'city': u'',
#    u'id': 116,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:26 PM',
#    u'latitude': 40.74177603,
#    u'location': u'',
#    u'longitude': -74.00149746,
#    u'postalCode': u'',
#    u'stAddress1': u'W 17 St & 8 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 17 St & 8 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 7,
#    u'city': u'',
#    u'id': 119,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:06 PM',
#    u'latitude': 40.69608941,
#    u'location': u'',
#    u'longitude': -73.97803415,
#    u'postalCode': u'',
#    u'stAddress1': u'Park Ave & St Edwards St',
#    u'stAddress2': u'',
#    u'stationName': u'Park Ave & St Edwards St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 5,
#    u'city': u'',
#    u'id': 120,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:22 PM',
#    u'latitude': 40.68676793,
#    u'location': u'',
#    u'longitude': -73.95928168,
#    u'postalCode': u'',
#    u'stAddress1': u'Lexington Ave & Classon Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Lexington Ave & Classon Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 26,
#    u'city': u'',
#    u'id': 127,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:32 PM',
#    u'latitude': 40.73172428,
#    u'location': u'',
#    u'longitude': -74.00674436,
#    u'postalCode': u'',
#    u'stAddress1': u'Barrow St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Barrow St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 21,
#    u'availableDocks': 7,
#    u'city': u'',
#    u'id': 128,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:38 PM',
#    u'latitude': 40.72710258,
#    u'location': u'',
#    u'longitude': -74.00297088,
#    u'postalCode': u'',
#    u'stAddress1': u'MacDougal St & Prince St',
#    u'stAddress2': u'',
#    u'stationName': u'MacDougal St & Prince St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 30},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 137,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'1969-12-31 07:00:00 PM',
#    u'latitude': 40.761628,
#    u'location': u'',
#    u'longitude': -73.972924,
#    u'postalCode': u'',
#    u'stAddress1': u'E 56 St & Madison Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 56 St & Madison Ave',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 0},
#   {u'altitude': u'',
#    u'availableBikes': 15,
#    u'availableDocks': 7,
#    u'city': u'',
#    u'id': 143,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:08 PM',
#    u'latitude': 40.69239502,
#    u'location': u'',
#    u'longitude': -73.99337909,
#    u'postalCode': u'',
#    u'stAddress1': u'Clinton St & Joralemon St',
#    u'stAddress2': u'',
#    u'stationName': u'Clinton St & Joralemon St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 15,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 144,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:21 PM',
#    u'latitude': 40.69839895,
#    u'location': u'',
#    u'longitude': -73.98068914,
#    u'postalCode': u'',
#    u'stAddress1': u'Nassau St & Navy St',
#    u'stAddress2': u'',
#    u'stationName': u'Nassau St & Navy St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 25,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 146,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:17 PM',
#    u'latitude': 40.71625008,
#    u'location': u'',
#    u'longitude': -74.0091059,
#    u'postalCode': u'',
#    u'stAddress1': u'Hudson St & Reade St',
#    u'stAddress2': u'',
#    u'stationName': u'Hudson St & Reade St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 147,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-02-23 09:48:26 AM',
#    u'latitude': 40.71542197,
#    u'location': u'',
#    u'longitude': -74.01121978,
#    u'postalCode': u'',
#    u'stAddress1': u'Greenwich St & Warren St',
#    u'stAddress2': u'',
#    u'stationName': u'Greenwich St & Warren St',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 0},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 150,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:44 PM',
#    u'latitude': 40.7208736,
#    u'location': u'',
#    u'longitude': -73.98085795,
#    u'postalCode': u'',
#    u'stAddress1': u'E 2 St & Avenue C',
#    u'stAddress2': u'',
#    u'stationName': u'E 2 St & Avenue C',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 151,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:10 PM',
#    u'latitude': 40.722103786686034,
#    u'location': u'',
#    u'longitude': -73.99724900722504,
#    u'postalCode': u'',
#    u'stAddress1': u'Cleveland Pl & Spring St',
#    u'stAddress2': u'',
#    u'stationName': u'Cleveland Pl & Spring St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 24,
#    u'availableDocks': 4,
#    u'city': u'',
#    u'id': 152,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:44 PM',
#    u'latitude': 40.71473993,
#    u'location': u'',
#    u'longitude': -74.00910627,
#    u'postalCode': u'',
#    u'stAddress1': u'Warren St & Church St',
#    u'stAddress2': u'',
#    u'stationName': u'Warren St & Church St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 54,
#    u'city': u'',
#    u'id': 153,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:31 PM',
#    u'latitude': 40.752062307,
#    u'location': u'',
#    u'longitude': -73.9816324043,
#    u'postalCode': u'',
#    u'stAddress1': u'E 40 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 40 St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 157,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:05 PM',
#    u'latitude': 40.69089272,
#    u'location': u'',
#    u'longitude': -73.99612349,
#    u'postalCode': u'',
#    u'stAddress1': u'Henry St & Atlantic Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Henry St & Atlantic Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 18,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 161,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:01 PM',
#    u'latitude': 40.72917025,
#    u'location': u'',
#    u'longitude': -73.99810231,
#    u'postalCode': u'',
#    u'stAddress1': u'LaGuardia Pl & W 3 St',
#    u'stAddress2': u'',
#    u'stationName': u'LaGuardia Pl & W 3 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 46,
#    u'city': u'',
#    u'id': 164,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:43 PM',
#    u'latitude': 40.75323098,
#    u'location': u'',
#    u'longitude': -73.97032517,
#    u'postalCode': u'',
#    u'stAddress1': u'E 47 St & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 47 St & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 41,
#    u'city': u'',
#    u'id': 167,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:46 PM',
#    u'latitude': 40.7489006,
#    u'location': u'',
#    u'longitude': -73.97604882,
#    u'postalCode': u'',
#    u'stAddress1': u'E 39 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 39 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 45},
#   {u'altitude': u'',
#    u'availableBikes': 40,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 168,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:10 PM',
#    u'latitude': 40.73971301,
#    u'location': u'',
#    u'longitude': -73.99456405,
#    u'postalCode': u'',
#    u'stAddress1': u'W 18 St & 6 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 18 St & 6 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 31,
#    u'city': u'',
#    u'id': 173,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:55 PM',
#    u'latitude': 40.76068327096592,
#    u'location': u'',
#    u'longitude': -73.9845272898674,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & W 49 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & W 49 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 51},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 174,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:57 PM',
#    u'latitude': 40.7381765,
#    u'location': u'',
#    u'longitude': -73.97738662,
#    u'postalCode': u'',
#    u'stAddress1': u'E 25 St & 1 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 25 St & 1 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 30},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 37,
#    u'city': u'',
#    u'id': 195,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:59 PM',
#    u'latitude': 40.70905623,
#    u'location': u'',
#    u'longitude': -74.01043382,
#    u'postalCode': u'',
#    u'stAddress1': u'Liberty St & Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Liberty St & Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 45},
#   {u'altitude': u'',
#    u'availableBikes': 20,
#    u'availableDocks': 6,
#    u'city': u'',
#    u'id': 212,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:02 PM',
#    u'latitude': 40.74334935,
#    u'location': u'',
#    u'longitude': -74.00681753,
#    u'postalCode': u'',
#    u'stAddress1': u'W 16 St & The High Line',
#    u'stAddress2': u'',
#    u'stationName': u'W 16 St & The High Line',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 28},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 216,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:10 PM',
#    u'latitude': 40.70037867,
#    u'location': u'',
#    u'longitude': -73.99548059,
#    u'postalCode': u'',
#    u'stAddress1': u'Columbia Heights & Cranberry St',
#    u'stAddress2': u'',
#    u'stationName': u'Columbia Heights & Cranberry St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 18,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 217,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:50 PM',
#    u'latitude': 40.70277159,
#    u'location': u'',
#    u'longitude': -73.99383605,
#    u'postalCode': u'',
#    u'stAddress1': u'Old Fulton St',
#    u'stAddress2': u'',
#    u'stationName': u'Old Fulton St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 223,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:42 PM',
#    u'latitude': 40.73781509,
#    u'location': u'',
#    u'longitude': -73.99994661,
#    u'postalCode': u'',
#    u'stAddress1': u'W 13 St & 7 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 13 St & 7 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 224,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-31 08:19:56 AM',
#    u'latitude': 40.71146364,
#    u'location': u'',
#    u'longitude': -74.00552427,
#    u'postalCode': u'',
#    u'stAddress1': u'Spruce St & Nassau St',
#    u'stAddress2': u'',
#    u'stationName': u'Spruce St & Nassau St',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 3},
#   {u'altitude': u'',
#    u'availableBikes': 36,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 225,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:11 PM',
#    u'latitude': 40.74195138,
#    u'location': u'',
#    u'longitude': -74.00803013,
#    u'postalCode': u'',
#    u'stAddress1': u'W 14 St & The High Line',
#    u'stAddress2': u'',
#    u'stationName': u'W 14 St & The High Line',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 50,
#    u'city': u'',
#    u'id': 228,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:06 PM',
#    u'latitude': 40.7546011026,
#    u'location': u'',
#    u'longitude': -73.971878855,
#    u'postalCode': u'',
#    u'stAddress1': u'E 48 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 48 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 23,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 229,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:29 PM',
#    u'latitude': 40.72743423,
#    u'location': u'',
#    u'longitude': -73.99379025,
#    u'postalCode': u'',
#    u'stAddress1': u'Great Jones St',
#    u'stAddress2': u'',
#    u'stationName': u'Great Jones St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 232,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:41 PM',
#    u'latitude': 40.69597683,
#    u'location': u'',
#    u'longitude': -73.99014892,
#    u'postalCode': u'',
#    u'stAddress1': u'Cadman Plaza E & Tillary St',
#    u'stAddress2': u'',
#    u'stationName': u'Cadman Plaza E & Tillary St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 25,
#    u'city': u'',
#    u'id': 236,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:35 PM',
#    u'latitude': 40.7284186,
#    u'location': u'',
#    u'longitude': -73.98713956,
#    u'postalCode': u'',
#    u'stAddress1': u'St Marks Pl & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'St Marks Pl & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 26,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 237,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:35 PM',
#    u'latitude': 40.73047309,
#    u'location': u'',
#    u'longitude': -73.98672378,
#    u'postalCode': u'',
#    u'stAddress1': u'E 11 St & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 11 St & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 28,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 238,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:32 PM',
#    u'latitude': 40.7361967,
#    u'location': u'',
#    u'longitude': -74.00859207,
#    u'postalCode': u'',
#    u'stAddress1': u'Bank St & Washington St',
#    u'stAddress2': u'',
#    u'stationName': u'Bank St & Washington St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 30,
#    u'city': u'',
#    u'id': 239,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:41 PM',
#    u'latitude': 40.69196566,
#    u'location': u'',
#    u'longitude': -73.9813018,
#    u'postalCode': u'',
#    u'stAddress1': u'Willoughby St & Fleet St',
#    u'stAddress2': u'',
#    u'stationName': u'Willoughby St & Fleet St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 241,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:06 PM',
#    u'latitude': 40.68981035,
#    u'location': u'',
#    u'longitude': -73.97493121,
#    u'postalCode': u'',
#    u'stAddress1': u'DeKalb Ave & S Portland Ave',
#    u'stAddress2': u'',
#    u'stationName': u'DeKalb Ave & S Portland Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 7,
#    u'city': u'',
#    u'id': 242,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:39 PM',
#    u'latitude': 40.697787,
#    u'location': u'',
#    u'longitude': -73.973736,
#    u'postalCode': u'',
#    u'stAddress1': u'Carlton Ave & Flushing Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Carlton Ave & Flushing Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 29,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 243,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:41 PM',
#    u'latitude': 40.688226,
#    u'location': u'',
#    u'longitude': -73.979382,
#    u'postalCode': u'',
#    u'stAddress1': u'Fulton St & Rockwell Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Fulton St & Rockwell Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 244,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:14 PM',
#    u'latitude': 40.69196035,
#    u'location': u'',
#    u'longitude': -73.96536851,
#    u'postalCode': u'',
#    u'stAddress1': u'Willoughby Ave & Hall St',
#    u'stAddress2': u'',
#    u'stationName': u'Willoughby Ave & Hall St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 245,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:11 PM',
#    u'latitude': 40.69327018,
#    u'location': u'',
#    u'longitude': -73.97703874,
#    u'postalCode': u'',
#    u'stAddress1': u'Myrtle Ave & St Edwards St',
#    u'stAddress2': u'',
#    u'stationName': u'Myrtle Ave & St Edwards St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 247,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:54 PM',
#    u'latitude': 40.73535398,
#    u'location': u'',
#    u'longitude': -74.00483091,
#    u'postalCode': u'',
#    u'stAddress1': u'Perry St & Bleecker St',
#    u'stAddress2': u'',
#    u'stationName': u'Perry St & Bleecker St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 20},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 248,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:20 PM',
#    u'latitude': 40.72185379,
#    u'location': u'',
#    u'longitude': -74.00771779,
#    u'postalCode': u'',
#    u'stAddress1': u'Laight St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Laight St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 23,
#    u'availableDocks': 4,
#    u'city': u'',
#    u'id': 249,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:34 PM',
#    u'latitude': 40.71870987,
#    u'location': u'',
#    u'longitude': -74.0090009,
#    u'postalCode': u'',
#    u'stAddress1': u'Harrison St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Harrison St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 26,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 251,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:49 PM',
#    u'latitude': 40.72317958,
#    u'location': u'',
#    u'longitude': -73.99480012,
#    u'postalCode': u'',
#    u'stAddress1': u'Mott St & Prince St',
#    u'stAddress2': u'',
#    u'stationName': u'Mott St & Prince St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 30,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 252,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:10 PM',
#    u'latitude': 40.73226398,
#    u'location': u'',
#    u'longitude': -73.99852205,
#    u'postalCode': u'',
#    u'stAddress1': u'MacDougal St & Washington Sq',
#    u'stAddress2': u'',
#    u'stationName': u'MacDougal St & Washington Sq',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 44,
#    u'city': u'',
#    u'id': 253,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:05 PM',
#    u'latitude': 40.73543934,
#    u'location': u'',
#    u'longitude': -73.99453948,
#    u'postalCode': u'',
#    u'stAddress1': u'W 13 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 13 St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 254,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:37 PM',
#    u'latitude': 40.73532427,
#    u'location': u'',
#    u'longitude': -73.99800419,
#    u'postalCode': u'',
#    u'stAddress1': u'W 11 St & 6 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 11 St & 6 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 38,
#    u'city': u'',
#    u'id': 257,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:08 PM',
#    u'latitude': 40.71939226,
#    u'location': u'',
#    u'longitude': -74.00247214,
#    u'postalCode': u'',
#    u'stAddress1': u'Lispenard St & Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Lispenard St & Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 258,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:07 PM',
#    u'latitude': 40.68940747,
#    u'location': u'',
#    u'longitude': -73.96885458,
#    u'postalCode': u'',
#    u'stAddress1': u'DeKalb Ave & Vanderbilt Ave',
#    u'stAddress2': u'',
#    u'stationName': u'DeKalb Ave & Vanderbilt Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 28,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 259,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:03 PM',
#    u'latitude': 40.70122128,
#    u'location': u'',
#    u'longitude': -74.01234218,
#    u'postalCode': u'',
#    u'stAddress1': u'South St & Whitehall St',
#    u'stAddress2': u'',
#    u'stationName': u'South St & Whitehall St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 34,
#    u'city': u'',
#    u'id': 260,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:19 PM',
#    u'latitude': 40.70365182,
#    u'location': u'',
#    u'longitude': -74.01167797,
#    u'postalCode': u'',
#    u'stAddress1': u'Broad St & Bridge St',
#    u'stAddress2': u'',
#    u'stationName': u'Broad St & Bridge St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 261,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:12 PM',
#    u'latitude': 40.69474881,
#    u'location': u'',
#    u'longitude': -73.98362464,
#    u'postalCode': u'',
#    u'stAddress1': u'Johnson St & Gold St',
#    u'stAddress2': u'',
#    u'stationName': u'Johnson St & Gold St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 262,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:32 PM',
#    u'latitude': 40.6917823,
#    u'location': u'',
#    u'longitude': -73.9737299,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Park',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 264,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:09 PM',
#    u'latitude': 40.70706456,
#    u'location': u'',
#    u'longitude': -74.00731853,
#    u'postalCode': u'',
#    u'stAddress1': u'Maiden Ln & Pearl St',
#    u'stAddress2': u'',
#    u'stationName': u'Maiden Ln & Pearl St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 265,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:30 PM',
#    u'latitude': 40.72229346,
#    u'location': u'',
#    u'longitude': -73.99147535,
#    u'postalCode': u'',
#    u'stAddress1': u'Stanton St & Chrystie St',
#    u'stAddress2': u'',
#    u'stationName': u'Stanton St & Chrystie St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 266,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:56 PM',
#    u'latitude': 40.72368361,
#    u'location': u'',
#    u'longitude': -73.97574813,
#    u'postalCode': u'',
#    u'stAddress1': u'Avenue D & E 8 St',
#    u'stAddress2': u'',
#    u'stationName': u'Avenue D & E 8 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 53,
#    u'city': u'',
#    u'id': 267,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:09 PM',
#    u'latitude': 40.75097711,
#    u'location': u'',
#    u'longitude': -73.98765428,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & W 36 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & W 36 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 57},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 268,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:53 PM',
#    u'latitude': 40.71910537,
#    u'location': u'',
#    u'longitude': -73.99973337,
#    u'postalCode': u'',
#    u'stAddress1': u'Howard St & Centre St',
#    u'stAddress2': u'',
#    u'stationName': u'Howard St & Centre St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 270,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:07 PM',
#    u'latitude': 40.69308257,
#    u'location': u'',
#    u'longitude': -73.97178913,
#    u'postalCode': u'',
#    u'stAddress1': u'Adelphi St & Myrtle Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Adelphi St & Myrtle Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 26,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 274,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:44 PM',
#    u'latitude': 40.68691865,
#    u'location': u'',
#    u'longitude': -73.976682,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette Ave & Fort Greene Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette Ave & Fort Greene Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 275,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:09 PM',
#    u'latitude': 40.68650065,
#    u'location': u'',
#    u'longitude': -73.96563307,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Ave & Greene Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Ave & Greene Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 23,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 276,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:05 PM',
#    u'latitude': 40.71748752,
#    u'location': u'',
#    u'longitude': -74.0104554,
#    u'postalCode': u'',
#    u'stAddress1': u'Duane St & Greenwich St',
#    u'stAddress2': u'',
#    u'stationName': u'Duane St & Greenwich St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 25},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 278,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:19 PM',
#    u'latitude': 40.69766564,
#    u'location': u'',
#    u'longitude': -73.98476437,
#    u'postalCode': u'',
#    u'stAddress1': u'Concord St & Bridge St',
#    u'stAddress2': u'',
#    u'stationName': u'Concord St & Bridge St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 20,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 279,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:12 PM',
#    u'latitude': 40.707873,
#    u'location': u'',
#    u'longitude': -74.00167,
#    u'postalCode': u'',
#    u'stAddress1': u'Peck Slip & Front St',
#    u'stAddress2': u'',
#    u'stationName': u'Peck Slip & Front St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 36},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 280,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:17 PM',
#    u'latitude': 40.73331967,
#    u'location': u'',
#    u'longitude': -73.99510132,
#    u'postalCode': u'',
#    u'stAddress1': u'E 10 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 10 St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 44,
#    u'city': u'',
#    u'id': 281,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:34 PM',
#    u'latitude': 40.7643971,
#    u'location': u'',
#    u'longitude': -73.97371465,
#    u'postalCode': u'',
#    u'stAddress1': u'Grand Army Plaza & Central Park S',
#    u'stAddress2': u'',
#    u'stationName': u'Grand Army Plaza & Central Park S',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 59},
#   {u'altitude': u'',
#    u'availableBikes': 13,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 282,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:19 PM',
#    u'latitude': 40.707644944175705,
#    u'location': u'',
#    u'longitude': -73.96841526031494,
#    u'postalCode': u'',
#    u'stAddress1': u'Kent Ave & S 11 St',
#    u'stAddress2': u'',
#    u'stationName': u'Kent Ave & S 11 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 284,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:47 PM',
#    u'latitude': 40.7390169121,
#    u'location': u'',
#    u'longitude': -74.0026376103,
#    u'postalCode': u'',
#    u'stAddress1': u'Greenwich Ave & 8 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Greenwich Ave & 8 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 43},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 285,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-29 11:32:04 AM',
#    u'latitude': 40.73454567,
#    u'location': u'',
#    u'longitude': -73.99074142,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & E 14 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & E 14 St',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 0},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 289,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:00 PM',
#    u'latitude': 40.6845683,
#    u'location': u'',
#    u'longitude': -73.95881081,
#    u'postalCode': u'',
#    u'stAddress1': u'Monroe St & Classon Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Monroe St & Classon Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 291,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:41 PM',
#    u'latitude': 40.713126,
#    u'location': u'',
#    u'longitude': -73.984844,
#    u'postalCode': u'',
#    u'stAddress1': u'Madison St & Montgomery St',
#    u'stAddress2': u'',
#    u'stationName': u'Madison St & Montgomery St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 20},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 46,
#    u'city': u'',
#    u'id': 293,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:24 PM',
#    u'latitude': 40.73020660529954,
#    u'location': u'',
#    u'longitude': -73.99102628231049,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette St & E 8 St',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette St & E 8 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 295,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:16 PM',
#    u'latitude': 40.71406667,
#    u'location': u'',
#    u'longitude': -73.99293911,
#    u'postalCode': u'',
#    u'stAddress1': u'Pike St & E Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Pike St & E Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 18,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 296,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:07 PM',
#    u'latitude': 40.71413089,
#    u'location': u'',
#    u'longitude': -73.9970468,
#    u'postalCode': u'',
#    u'stAddress1': u'Division St & Bowery',
#    u'stAddress2': u'',
#    u'stationName': u'Division St & Bowery',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 297,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:15 PM',
#    u'latitude': 40.734232,
#    u'location': u'',
#    u'longitude': -73.986923,
#    u'postalCode': u'',
#    u'stAddress1': u'E 15 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 15 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 24,
#    u'city': u'',
#    u'id': 301,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:31 PM',
#    u'latitude': 40.72217444,
#    u'location': u'',
#    u'longitude': -73.98368779,
#    u'postalCode': u'',
#    u'stAddress1': u'E 2 St & Avenue B',
#    u'stAddress2': u'',
#    u'stationName': u'E 2 St & Avenue B',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 302,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:26 PM',
#    u'latitude': 40.72082834,
#    u'location': u'',
#    u'longitude': -73.97793172,
#    u'postalCode': u'',
#    u'stAddress1': u'Avenue D & E 3 St',
#    u'stAddress2': u'',
#    u'stationName': u'Avenue D & E 3 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 303,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:35 PM',
#    u'latitude': 40.72362738,
#    u'location': u'',
#    u'longitude': -73.99949601,
#    u'postalCode': u'',
#    u'stAddress1': u'Mercer St & Spring St',
#    u'stAddress2': u'',
#    u'stationName': u'Mercer St & Spring St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 30,
#    u'city': u'',
#    u'id': 304,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:08 PM',
#    u'latitude': 40.70463334,
#    u'location': u'',
#    u'longitude': -74.01361706,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & Battery Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & Battery Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 34},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 305,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:37 PM',
#    u'latitude': 40.76095756,
#    u'location': u'',
#    u'longitude': -73.96724467,
#    u'postalCode': u'',
#    u'stAddress1': u'E 58 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 58 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 36,
#    u'city': u'',
#    u'id': 306,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:59 PM',
#    u'latitude': 40.70823502,
#    u'location': u'',
#    u'longitude': -74.00530063,
#    u'postalCode': u'',
#    u'stAddress1': u'Cliff St & Fulton St',
#    u'stAddress2': u'',
#    u'stationName': u'Cliff St & Fulton St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 18,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 307,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:27 PM',
#    u'latitude': 40.71427487,
#    u'location': u'',
#    u'longitude': -73.98990025,
#    u'postalCode': u'',
#    u'stAddress1': u'Canal St & Rutgers St',
#    u'stAddress2': u'',
#    u'stationName': u'Canal St & Rutgers St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 308,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:47 PM',
#    u'latitude': 40.71307916,
#    u'location': u'',
#    u'longitude': -73.99851193,
#    u'postalCode': u'',
#    u'stAddress1': u'St James Pl & Oliver St',
#    u'stAddress2': u'',
#    u'stationName': u'St James Pl & Oliver St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 36,
#    u'availableDocks': 5,
#    u'city': u'',
#    u'id': 309,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:07 PM',
#    u'latitude': 40.7149787,
#    u'location': u'',
#    u'longitude': -74.013012,
#    u'postalCode': u'',
#    u'stAddress1': u'Murray St & West St',
#    u'stAddress2': u'',
#    u'stationName': u'Murray St & West St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 41},
#   {u'altitude': u'',
#    u'availableBikes': 27,
#    u'availableDocks': 7,
#    u'city': u'',
#    u'id': 310,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:57 PM',
#    u'latitude': 40.68926942,
#    u'location': u'',
#    u'longitude': -73.98912867,
#    u'postalCode': u'',
#    u'stAddress1': u'State St & Smith St',
#    u'stAddress2': u'',
#    u'stationName': u'State St & Smith St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 36},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 311,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:08 PM',
#    u'latitude': 40.7172274,
#    u'location': u'',
#    u'longitude': -73.98802084,
#    u'postalCode': u'',
#    u'stAddress1': u'Norfolk St & Broome St',
#    u'stAddress2': u'',
#    u'stationName': u'Norfolk St & Broome St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 312,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:32 PM',
#    u'latitude': 40.722055,
#    u'location': u'',
#    u'longitude': -73.989111,
#    u'postalCode': u'',
#    u'stAddress1': u'Allen St & Stanton St',
#    u'stAddress2': u'',
#    u'stationName': u'Allen St & Stanton St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 21,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 313,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:56 PM',
#    u'latitude': 40.69610226,
#    u'location': u'',
#    u'longitude': -73.96751037,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Ave & Park Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Ave & Park Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 23,
#    u'city': u'',
#    u'id': 314,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:58 PM',
#    u'latitude': 40.69383,
#    u'location': u'',
#    u'longitude': -73.990539,
#    u'postalCode': u'',
#    u'stAddress1': u'Cadman Plaza West & Montague St',
#    u'stAddress2': u'',
#    u'stationName': u'Cadman Plaza West & Montague St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 315,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:05 PM',
#    u'latitude': 40.70355377,
#    u'location': u'',
#    u'longitude': -74.00670227,
#    u'postalCode': u'',
#    u'stAddress1': u'South St & Gouverneur Ln',
#    u'stAddress2': u'',
#    u'stationName': u'South St & Gouverneur Ln',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 38,
#    u'city': u'',
#    u'id': 316,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:59 PM',
#    u'latitude': 40.70955958,
#    u'location': u'',
#    u'longitude': -74.00653609,
#    u'postalCode': u'',
#    u'stAddress1': u'Fulton St & William St',
#    u'stAddress2': u'',
#    u'stationName': u'Fulton St & William St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 43},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 317,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:14 PM',
#    u'latitude': 40.72453734,
#    u'location': u'',
#    u'longitude': -73.98185424,
#    u'postalCode': u'',
#    u'stAddress1': u'E 6 St & Avenue B',
#    u'stAddress2': u'',
# ...
#    u'location': u'',
#    u'longitude': -73.97324283,
#    u'postalCode': u'',
#    u'stAddress1': u'7 Ave & Park Pl',
#    u'stAddress2': u'',
#    u'stationName': u'7 Ave & Park Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 17},
#   {u'altitude': u'',
#    u'availableBikes': 26,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 3417,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:26 PM',
#    u'latitude': 40.6795766,
#    u'location': u'',
#    u'longitude': -73.97854971,
#    u'postalCode': u'',
#    u'stAddress1': u'Baltic St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Baltic St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 30,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 3418,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:55 PM',
#    u'latitude': 40.6750207,
#    u'location': u'',
#    u'longitude': -73.97111473,
#    u'postalCode': u'',
#    u'stAddress1': u'Plaza St West & Flatbush Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Plaza St West & Flatbush Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 27,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 3419,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:05 PM',
#    u'latitude': 40.6792788,
#    u'location': u'',
#    u'longitude': -73.98154004,
#    u'postalCode': u'',
#    u'stAddress1': u'Douglass St & 4 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Douglass St & 4 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 5,
#    u'city': u'',
#    u'id': 3420,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:35 PM',
#    u'latitude': 40.6802133,
#    u'location': u'',
#    u'longitude': -73.98432695,
#    u'postalCode': u'',
#    u'stAddress1': u'Douglass St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Douglass St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 21},
#   {u'altitude': u'',
#    u'availableBikes': 13,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 3421,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:44 PM',
#    u'latitude': 40.6843549,
#    u'location': u'',
#    u'longitude': -73.98901629,
#    u'postalCode': u'',
#    u'stAddress1': u'Hoyt St & Warren St',
#    u'stAddress2': u'',
#    u'stationName': u'Hoyt St & Warren St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 20,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 3422,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:53 PM',
#    u'latitude': 40.6859296,
#    u'location': u'',
#    u'longitude': -74.00242364,
#    u'postalCode': u'',
#    u'stAddress1': u'Columbia St & Degraw St',
#    u'stAddress2': u'',
#    u'stationName': u'Columbia St & Degraw St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 21},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 3423,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:27 PM',
#    u'latitude': 40.6610633719006,
#    u'location': u'',
#    u'longitude': -73.97945255041122,
#    u'postalCode': u'',
#    u'stAddress1': u'West Drive & Prospect Park West',
#    u'stAddress2': u'',
#    u'stationName': u'West Drive & Prospect Park West',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 5,
#    u'city': u'',
#    u'id': 3424,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:04 PM',
#    u'latitude': 40.791976,
#    u'location': u'',
#    u'longitude': -73.945993,
#    u'postalCode': u'',
#    u'stAddress1': u'E 106 St & Lexington Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 106 St & Lexington Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 3425,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:37 PM',
#    u'latitude': 40.7892105,
#    u'location': u'',
#    u'longitude': -73.94370784,
#    u'postalCode': u'',
#    u'stAddress1': u'2 Ave  & E 104 St',
#    u'stAddress2': u'',
#    u'stationName': u'2 Ave  & E 104 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 13,
#    u'availableDocks': 26,
#    u'city': u'',
#    u'id': 3427,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:29 PM',
#    u'latitude': 40.72430527250332,
#    u'location': u'',
#    u'longitude': -73.99600982666016,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette St & Jersey St',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette St & Jersey St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 40},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 3428,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:52 PM',
#    u'latitude': 40.740983,
#    u'location': u'',
#    u'longitude': -74.001702,
#    u'postalCode': u'',
#    u'stAddress1': u'8 Ave & W 16 St',
#    u'stAddress2': u'',
#    u'stationName': u'8 Ave & W 16 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 25},
#   {u'altitude': u'',
#    u'availableBikes': 27,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 3429,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:52 PM',
#    u'latitude': 40.68506807308177,
#    u'location': u'',
#    u'longitude': -73.97790759801863,
#    u'postalCode': u'',
#    u'stAddress1': u'Hanson Pl & Ashland Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Hanson Pl & Ashland Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 3430,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:15 PM',
#    u'latitude': 40.71907891179564,
#    u'location': u'',
#    u'longitude': -73.94223690032959,
#    u'postalCode': u'',
#    u'stAddress1': u'Richardson St & N Henry St',
#    u'stAddress2': u'',
#    u'stationName': u'Richardson St & N Henry St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 3431,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:09 PM',
#    u'latitude': 40.746524,
#    u'location': u'',
#    u'longitude': -73.977885,
#    u'postalCode': u'',
#    u'stAddress1': u'E 35 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 35 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 26},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 32,
#    u'city': u'',
#    u'id': 3434,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:17 PM',
#    u'latitude': 40.79025417330419,
#    u'location': u'',
#    u'longitude': -73.97718340158461,
#    u'postalCode': u'',
#    u'stAddress1': u'W 88 St & West End Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 88 St & West End Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 36,
#    u'city': u'',
#    u'id': 3435,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:16 PM',
#    u'latitude': 40.718822,
#    u'location': u'',
#    u'longitude': -73.99596,
#    u'postalCode': u'',
#    u'stAddress1': u'Grand St & Elizabeth St',
#    u'stAddress2': u'',
#    u'stationName': u'Grand St & Elizabeth St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 45},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 3436,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:52 PM',
#    u'latitude': 40.721319,
#    u'location': u'',
#    u'longitude': -74.010065,
#    u'postalCode': u'',
#    u'stAddress1': u'Greenwich St & Hubert St',
#    u'stAddress2': u'',
#    u'stationName': u'Greenwich St & Hubert St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 3438,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:59 PM',
#    u'latitude': 40.772248537721744,
#    u'location': u'',
#    u'longitude': -73.95842134952545,
#    u'postalCode': u'',
#    u'stAddress1': u'E 76 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 76 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 24,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 3440,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:54 PM',
#    u'latitude': 40.692418292578466,
#    u'location': u'',
#    u'longitude': -73.98949474096298,
#    u'postalCode': u'',
#    u'stAddress1': u'Fulton St & Adams St',
#    u'stAddress2': u'',
#    u'stationName': u'Fulton St & Adams St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 43},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 35,
#    u'city': u'',
#    u'id': 3443,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:31 PM',
#    u'latitude': 40.76132983124814,
#    u'location': u'',
#    u'longitude': -73.97982001304626,
#    u'postalCode': u'',
#    u'stAddress1': u'W 52 St & 6 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 52 St & 6 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 3445,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:32 PM',
#    u'latitude': 40.79181171501097,
#    u'location': u'',
#    u'longitude': -73.9786022901535,
#    u'postalCode': u'',
#    u'stAddress1': u'Riverside Dr & W 89 St',
#    u'stAddress2': u'',
#    u'stationName': u'Riverside Dr & W 89 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 3447,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:55 PM',
#    u'latitude': 40.76703432309872,
#    u'location': u'',
#    u'longitude': -73.95622730255127,
#    u'postalCode': u'',
#    u'stAddress1': u'E 71 St & 1 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 71 St & 1 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 41},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 3449,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:41 PM',
#    u'latitude': 40.721462562298164,
#    u'location': u'',
#    u'longitude': -73.94800901412964,
#    u'postalCode': u'',
#    u'stAddress1': u'Eckford St & Engert Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Eckford St & Engert Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 41,
#    u'city': u'',
#    u'id': 3452,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:42 PM',
#    u'latitude': 40.71915571696044,
#    u'location': u'',
#    u'longitude': -73.94885390996933,
#    u'postalCode': u'',
#    u'stAddress1': u'Bayard St & Leonard St',
#    u'stAddress2': u'',
#    u'stationName': u'Bayard St & Leonard St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 43},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 5,
#    u'city': u'',
#    u'id': 3453,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:44 PM',
#    u'latitude': 40.71335226222875,
#    u'location': u'',
#    u'longitude': -73.9491033554077,
#    u'postalCode': u'',
#    u'stAddress1': u'Devoe St & Lorimer St',
#    u'stAddress2': u'',
#    u'stationName': u'Devoe St & Lorimer St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 3454,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:31:48 PM',
#    u'latitude': 40.7103685423523,
#    u'location': u'',
#    u'longitude': -73.94705951213837,
#    u'postalCode': u'',
#    u'stAddress1': u'Leonard St & Maujer St',
#    u'stAddress2': u'',
#    u'stationName': u'Leonard St & Maujer St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 15,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 3455,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:52 PM',
#    u'latitude': 40.68680820503432,
#    u'location': u'',
#    u'longitude': -73.98036181926727,
#    u'postalCode': u'',
#    u'stAddress1': u'Schermerhorn St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Schermerhorn St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 3456,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:01 PM',
#    u'latitude': 40.71638031973561,
#    u'location': u'',
#    u'longitude': -73.94821286201477,
#    u'postalCode': u'',
#    u'stAddress1': u'Jackson St & Leonard St',
#    u'stAddress2': u'',
#    u'stationName': u'Jackson St & Leonard St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 22},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 33,
#    u'city': u'',
#    u'id': 3459,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:33:34 PM',
#    u'latitude': 40.75763227739443,
#    u'location': u'',
#    u'longitude': -73.96930575370789,
#    u'postalCode': u'',
#    u'stAddress1': u'E 53 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 53 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 34},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 33,
#    u'city': u'',
#    u'id': 3462,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:32:27 PM',
#    u'latitude': 40.75118387463277,
#    u'location': u'',
#    u'longitude': -73.97138714790344,
#    u'postalCode': u'',
#    u'stAddress1': u'E 44 St & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 44 St & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 25,
#    u'city': u'',
#    u'id': 3463,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-04-23 07:30:50 PM',
#    u'latitude': 40.735367055605394,
#    u'location': u'',
#    u'longitude': -73.98797392845154,
#    u'postalCode': u'',
#    u'stAddress1': u'E 16 St & Irving Pl',
#    u'stAddress2': u'',
#    u'stationName': u'E 16 St & Irving Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37}]}

# %%
st = map(lambda x: (x['id'],x['latitude'], x['longitude'], x['stAddress1']),stations['stationBeanList'])

# %%
cb_stations = pd.DataFrame(st, columns=['id', 'latitude', 'longitude', 'station_address'])

# %%
cb_stations.duplicated().sum()
# Out:
# 0

# %%
cb_stations.head()
# Out:
#     id   latitude  longitude                station_address
# 0   72  40.767272 -73.993929               W 52 St & 11 Ave
# 1   79  40.719116 -74.006667       Franklin St & W Broadway
# 2   82  40.711174 -74.000165         St James Pl & Pearl St
# 3   83  40.683826 -73.976323  Atlantic Ave & Fort Greene Pl
# 4  116  40.741776 -74.001497                W 17 St & 8 Ave

# %% [markdown]
# # Taxi zones

# %%
tzones = gp.read_file("../../Data/taxi_zones/taxi_zones_updated.shp")

# %%
tzones.to_crs(epsg=4326, inplace=True)

# %% [markdown]
# # Merge all

# %%
def merge(stations, tzones):
    crs = {'init': 'epsg:4326', 'no_defs': True}
    geometry = [Point(xy) for xy in zip(stations["longitude"], stations["latitude"])]
    stations = stations.drop(["longitude", "latitude"], axis=1)
    stations = gp.GeoDataFrame(stations, crs=crs, geometry=geometry)
    
    print "Spatially joining cb_stations and taxi zones"
    stations_geo = gp.sjoin(tzones, stations) 
    stations_geo.drop(['borough', u'OBJECTID', 'Shape_Area', 'Shape_Leng',
                    u'geometry', 'index_right', 'zone'], axis = 1, inplace = True)  
    stations_geo.reset_index(inplace=True, drop=True)
    
    return stations_geo

# %%
def data_aggregator(data, stations_geo):
    data = data[['starttime', 'start station id']]
    data["starttime"] = pd.to_datetime(data["starttime"])

    data = pd.merge(data, stations_geo, left_on='start station id', right_on= 'id', how='left')
    data.dropna(inplace=True)
    data_agg = data.set_index('starttime').groupby([pd.TimeGrouper('D'),'LocationID']).agg({'start station id':'count'})
    data_agg.reset_index('LocationID', inplace=True)
    data_agg.columns = ['locationid', 'count']
    return data_agg

# %%
def citibike(years, months):
    
    '''Agrregate citibike data by taxi zones'''

#     year = ['2013', '2014', '2015', '2016']
#     months = ['07' ,'08', '09', '10', '11', '12']
#     months = ['01' ,'02', '03', '04', '05', '06', '07' ,'08', '09', '10', '11', '12']
    stations_geo = merge(cb_stations, tzones)
    
    citibike = pd.DataFrame()
    for y in years:
        for m in months:
            
            print "Reading Data/Citibike/" + y + m + "-citibike-tripdata.csv"
            data = pd.read_csv("../../Data/Citibike/" + y + m + "-citibike-tripdata.csv")
#             print "Cleaning columns"
#             data = clean_columns(data, y, m)
            print "Aggregating data"
            data_agg = data_aggregator(data, stations_geo)
            data_agg.to_csv("../../Data/Aggregated/individual_files/Citibike"+ y + "-" + m + ".csv")
            citibike = citibike.append(data_agg)
    
    return citibike

# %%
cb1 = citibike(['2013'], ['07', '08', '09', '10', '11', '12'])
# Out:
# Spatially joining cb_stations and taxi zones
# Reading Data/Citibike/201307-citibike-tripdata.csv
# Aggregating data
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# Reading Data/Citibike/201308-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201309-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201310-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201311-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201312-citibike-tripdata.csv
# Aggregating data

# %%
cb2 = citibike(years=['2014'], months = ['01' ,'02', '03', '04', '05', '06', '07' ,'08', '09', '10', '11', '12'])
# Out:
# Spatially joining cb_stations and taxi zones
# Reading Data/Citibike/201401-citibike-tripdata.csv
# Aggregating data
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# Reading Data/Citibike/201402-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201403-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201404-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201405-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201406-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201407-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201408-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201409-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201410-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201411-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201412-citibike-tripdata.csv
# Aggregating data

# %%
cb3 = citibike(years=['2015'], months = ['01' ,'02', '03', '04','06', '07' ,'08', '09', '10', '11', '12'])
# Out:
# Spatially joining cb_stations and taxi zones
# Reading Data/Citibike/201501-citibike-tripdata.csv
# Aggregating data
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# Reading Data/Citibike/201502-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201503-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201504-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201506-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201507-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201508-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201509-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201510-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201511-citibike-tripdata.csv
# Aggregating data
# Reading Data/Citibike/201512-citibike-tripdata.csv
# Aggregating data

# %%
cb4 = citibike(years=['2016'], months = ['01' ,'02', '03', '04', '05', '06', '07' ,'08', '09', '10', '11', '12'])

# %%
d = pd.read_csv("../../Data/Citibike/201505-citibike-tripdata.zip")

# %%
# data = d[['starttime', 'start station id']]
# data["starttime"] = pd.to_datetime(data["starttime"])

# data = pd.merge(data, stations_geo, left_on='start station id', right_on= 'id', how='left')
# data.dropna(inplace=True)
data_agg = data.set_index('starttime').groupby([pd.TimeGrouper('D'),'LocationID']).agg({'start station id':'count'})
data_agg.reset_index('LocationID', inplace=True)
data_agg.columns = ['locationid', 'count']

# %%
data_agg.to_csv("../../Data/Aggregated/individual_files/Citibike"+ '2015' + "-" + '05' + ".csv")

# %%
stations_geo = merge(cb_stations, tzones)
# Out:
# Spatially joining cb_stations and taxi zones
